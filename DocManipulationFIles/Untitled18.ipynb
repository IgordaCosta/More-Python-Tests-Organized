# %%
# this is to get the original text data information

##### this is all the steps to get the page general settings

from docx import Document

from bs4 import BeautifulSoup

import pprint


# OriginalDocument = 'TestDocNoChangeAllBoldArialBlack2.docx'


OriginalDocument = 'DifferentLineText6.docx'

Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'




LocOriginalDocument = Location + OriginalDocument


wordDocument = LocOriginalDocument


document = Document(wordDocument)


item = document.element.xml


soup = BeautifulSoup(item)



responseFind = soup.find('w:sectpr')

stringData = str(responseFind)

# print(stringData)



# pprint.pprint(item)

responseFind2 = soup.find('w:body').findChildren('w:p', recursive=False)



# pprint.pprint(responseFind2)

PprParagraphList= []
WrParagraphList= []
for i in responseFind2:
#     print(i)
#     print('=========================================')
    
    
    
    ppr = i.find_all('w:ppr')
    
    PprParagraphList.append(ppr)
    
    Wr = i.find_all('w:r')
    
    if Wr == []:
        pass
    
    else:   
        WrParagraphList.append(Wr)
    
### This shows text and text configuration (ex. underline, bold, italic etc)    
pprint.pprint(WrParagraphList)

print('===================================')
print('===================================')
print('===================================')

### this shows spacing
pprint.pprint(PprParagraphList)
# Out:
# [[<w:r>
# <w:t xml:space="preserve">This is part 1, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve">This is part 2, </w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve">Part3, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Part 4.</w:t>
# </w:r>],
#  [<w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new Paragraph</w:t>
# </w:r>]]
# ===================================
# ===================================
# ===================================
# [[<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>]]

# %%
pprint.pprint(WrParagraphList)
# Out:
# [[<w:r>
# <w:t xml:space="preserve">This is part 1, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve">This is part 2, </w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve">Part3, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Part 4.</w:t>
# </w:r>],
#  [<w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new Paragraph</w:t>
# </w:r>]]

# %%
WrParagraphList[0][1].find_all('w:rpr')
# Out:
# [<w:rpr>
#  <w:b></w:b>
#  </w:rpr>]

# %%
rprValueList = []

for Paragraph in WrParagraphList:
    
    for item in Paragraph:
                
        rprValue = item.find('w:rpr')
        
        if rprValue == None:
            rprValue = ''
        else:
            pass

        rprValueList.append(rprValue)
    
print(rprValueList)
# Out:
# 00000000000000000000000
# 00000000000000000000000
# 00000000000000000000000
# 00000000000000000000000
# 00000000000000000000000
# ['', <w:rpr>
# <w:b></w:b>
# </w:rpr>, '', <w:rpr>
# <w:i></w:i>
# </w:rpr>, <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>]

# %%
wtValueListText = ''
wtValueList = []
for Paragraph in WrParagraphList:
    
#     print(Paragraph)
    
    for item in Paragraph:
                
        wtValue = item.find('w:t')
        
#         print(wtValue)
        
        if wtValue == None:
            wtValue = ''
        else:
            pass

        wtValueList.append(wtValue.text)
        wtValueListText = wtValueListText + wtValue.text
    
pprint.pprint(wtValueList)

print(wtValueListText)

wtValueListText = wtValueListText.replace(" Ÿ", "")

wtValueListText = wtValueListText.replace("Ÿ", "")

print(wtValueListText)
# Out:
# ['This is part 1, ',
#  'This is part 2, ',
#  'Part3, ',
#  'Part 4.',
#  'This is the new Paragraph']
# This is part 1, This is part 2, Part3, Part 4.This is the new Paragraph
# This is part 1, This is part 2, Part3, Part 4.This is the new Paragraph

# %%
# this is to get the original text data information

##### this is all the steps to get the page general settings

from docx import Document

from bs4 import BeautifulSoup

import pprint


# OriginalDocument = 'TestDocNoChangeAllBoldArialBlack2.docx'


OriginalDocument = 'DifferentLineText6Changed.docx'

Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'




LocOriginalDocument = Location + OriginalDocument


wordDocument = LocOriginalDocument


document = Document(wordDocument)


item = document.element.xml


soup = BeautifulSoup(item)



responseFind = soup.find('w:sectpr')

stringData = str(responseFind)

# print(stringData)



# pprint.pprint(item)

responseFind2 = soup.find('w:body').findChildren('w:p', recursive=False)



# pprint.pprint(responseFind2)

PprParagraphList= []
WrParagraphList= []
for i in responseFind2:
#     print(i)
#     print('=========================================')
    
    
    
    ppr = i.find_all('w:ppr')
    
    PprParagraphList.append(ppr)
    
    Wr = i.find_all('w:r')
    
    if Wr == []:
        pass
    
    else:   
        WrParagraphList.append(Wr)

# %%
wtValueListText = ''
wtValueList = []
for Paragraph in WrParagraphList:
    
#     print(Paragraph)
    
    for item in Paragraph:
                
        wtValue = item.find('w:t')
        
#         print(wtValue)
        
        if wtValue == None:
            wtValue = ''
        else:
            pass

        wtValueList.append(wtValue.text)
        wtValueListText = wtValueListText + wtValue.text
    
pprint.pprint(wtValueList)

print(wtValueListText)

wtValueListText = wtValueListText.replace(" Ÿ", "")

wtValueListText = wtValueListText.replace("Ÿ", "")

print(wtValueListText)


wtValueList2 = wtValueList

wtValueListText2 = wtValueListText
# Out:
# ['This is',
#  ' Ÿ',
#  ' part 1, ',
#  'This',
#  ' Ÿ',
#  ' is part 2, ',
#  'Part',
#  ' Ÿ',
#  '3, ',
#  'Par',
#  ' ',
#  'Ÿ',
#  't',
#  ' 4.',
#  'This is the new',
#  ' Ÿ',
#  ' Paragraph']
# This is Ÿ part 1, This Ÿ is part 2, Part Ÿ3, Par Ÿt 4.This is the new Ÿ Paragraph
# This is part 1, This is part 2, Part3, Part 4.This is the new Paragraph

# %%
rprValueList = []

for Paragraph in WrParagraphList:
    
    for item in Paragraph:
                
        rprValue = item.find('w:rpr')
        
        if rprValue == None:
            rprValue = ''
        else:
            pass

        rprValueList.append(rprValue)
    
print(rprValueList)
# Out:
# ['', '', '', <w:rpr>
# <w:b></w:b>
# </w:rpr>, <w:rpr>
# <w:b></w:b>
# </w:rpr>, <w:rpr>
# <w:b></w:b>
# </w:rpr>, '', '', '', <w:rpr>
# <w:i></w:i>
# </w:rpr>, <w:rpr>
# <w:i></w:i>
# </w:rpr>, <w:rpr>
# <w:i></w:i>
# </w:rpr>, <w:rpr>
# <w:i></w:i>
# </w:rpr>, <w:rpr>
# <w:i></w:i>
# </w:rpr>, <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>, <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>, <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>]

# %%
wtValueList[0].text
# Out:
# 'This is'

# %%
pprint.pprint(wtValueList)


print(wtValueListText)

print('=====================================')

pprint.pprint(wtValueList2)


print(wtValueListText2)
# Out:
# ['This is part 1, ',
#  'This is part 2, ',
#  'Part3, ',
#  'Part 4.',
#  'This is the new Paragraph']
# This is part 1, This is part 2, Part3, Part 4.This is the new Paragraph
# =====================================
# ['This is',
#  ' Ÿ',
#  ' part 1, ',
#  'This',
#  ' Ÿ',
#  ' is part 2, ',
#  'Part',
#  ' Ÿ',
#  '3, ',
#  'Par',
#  ' ',
#  'Ÿ',
#  't',
#  ' 4.',
#  'This is the new',
#  ' Ÿ',
#  ' Paragraph']
# This is part 1, This is part 2, Part3, Part 4.This is the new Paragraph

# %%
if str(wtValueList) == str(wtValueList2):
    print("they are equal")
    
else:
    checkValue='-1'
    if len(wtValueList)> len(wtValueList2):
        print('wtValueList is greater')
        
        checkValue = '0'
        valueForFunction = wtValueList
        valueForFunctionLess = wtValueList2
    else:
        print('wtValueList2 is greater')
        
        checkValue = '1'
        valueForFunction = wtValueList2
        valueForFunctionLess = wtValueList
# Out:
# wtValueList2 is greater

# %%
print(checkValue)
print(valueForFunction)
print(valueForFunctionLess)
# Out:
# 1
# ['This is', ' Ÿ', ' part 1, ', 'This', ' Ÿ', ' is part 2, ', 'Part', ' Ÿ', '3, ', 'Par', ' ', 'Ÿ', 't', ' 4.', 'This is the new', ' Ÿ', ' Paragraph']
# ['This is part 1, ', 'This is part 2, ', 'Part3, ', 'Part 4.', 'This is the new Paragraph']

# %%
locationIsOk = False
wrongItemCount = 0

StartSentecePartList = []

StartSentecePart = -1

for i in range(len(valueForFunctionLess)):

    
    item = valueForFunctionLess[i]
    
#     print('===========================&&&&&&&&&&&&&&&&&&&&&&')
    
#     print(item)
    
#     print(len(item))
    

    

    startLetterLocation = -1
    
    for l in range(len(item)):
        
        letter = item[l]
        
#         print('letter checked: '+ str(letter))
        
 
        
        breakHappend = False
        for x in range(StartSentecePart, len(valueForFunction)):
                                    
            if breakHappend:
                print('another break happend 2')
                break

            
            
            
            print('StartSentecePart: ', str(StartSentecePart))
            
            
            senteceTocheck = valueForFunction[x]
            
#             print(senteceTocheck)
            
            
            for z in range(startLetterLocation , len(senteceTocheck)):
                
                
                if breakHappend:
                    print('another break happend')
                    break
                    
                    
                startLetterLocation  = startLetterLocation  + 1
                
                print('startLetterLocation : '+ str(startLetterLocation ))
                
                
                leterToCheck = senteceTocheck[z]
                
                
                
                if z == len(senteceTocheck) -1 :
                    startLetterLocation = -1
                    StartSentecePart = StartSentecePart + 1
                    
                
#                 print(leterToCheck)
                
                if leterToCheck == letter:
                    print('both letters the samce: '+ str(letter)+ ' and '+ str(leterToCheck))
                    
                    NumberOfSentecePartsList.append(StartSentecePart)
                
                    breakHappend = True
                    break

            
            
            print('#####')
    
    print('before adding to list StartSentecePart: '+ str(StartSentecePart))
    

    
    StartSentecePartList.append(StartSentecePart - 1)     
            
            
#             if breakHappend:
#                 break
            
#             BronkenSentence = valueForFunction[x]
            
#             for c in range(len(BronkenSentence)):
            
#                 LetterToCheck = c + LastLetterChecked

#                 if valueForFunction[LetterToCheck] == letter:
                    
#                     if l == len(item) -1:
#                         NumberOfSentecePartsList.append(x)
                    
#                     breakHappend = True
#                     break
                    
                    
        

    
    
    
# #     for letter in item:
        
    
# #         if locationIsOk:
        
# #             NumberOfSentecePartsList.append(wrongItemCount)


# #         locationIsOk = False
        
# #         wrongItemCount = 0
# #         for wrongItem in valueForFunction:
            
# #             wrongItemCount = wrongItemCount + 1
# #             for wrongLetter in wrongItem:
                
# #                 if letter == wrongLetter:
# #                     if 
# #                     locationIsOk = True
# #                     break
# #                 else:
# #                     pass
                
                
print(StartSentecePartList)
# Out:
# StartSentecePart:  -1
# startLetterLocation : 0
# startLetterLocation : 1
# startLetterLocation : 2
# startLetterLocation : 3
# startLetterLocation : 4
# startLetterLocation : 5
# startLetterLocation : 6
# startLetterLocation : 7
# startLetterLocation : 8
# startLetterLocation : 9
# startLetterLocation : 10
# #####
# StartSentecePart:  0
# startLetterLocation : 0
# startLetterLocation : 1
# both letters the samce: T and T
# #####
# another break happend 2
# StartSentecePart:  0
# startLetterLocation : 2
# both letters the samce: h and h
# #####
# another break happend 2
# StartSentecePart:  0
# startLetterLocation : 3
# both letters the samce: i and i
# #####
# another break happend 2
# StartSentecePart:  0
# startLetterLocation : 4
# both letters the samce: s and s
# #####
# another break happend 2
# StartSentecePart:  0
# startLetterLocation : 5
# both letters the samce:   and
# #####
# another break happend 2
# StartSentecePart:  0
# startLetterLocation : 6
# both letters the samce: i and i
# #####
# another break happend 2
# StartSentecePart:  0
# startLetterLocation : 7
# both letters the samce: s and s
# #####
# another break happend 2
# StartSentecePart:  1
# startLetterLocation : 0
# startLetterLocation : 1
# both letters the samce:   and
# #####
# another break happend 2
# StartSentecePart:  1
# startLetterLocation : 2
# #####
# StartSentecePart:  2
# startLetterLocation : 0
# startLetterLocation : 1
# startLetterLocation : 2
# both letters the samce: p and p
# #####
# another break happend 2
# StartSentecePart:  2
# startLetterLocation : 3
# both letters the samce: a and a
# #####
# another break happend 2
# StartSentecePart:  2
# startLetterLocation : 4
# both letters the samce: r and r
# #####
# another break happend 2
# StartSentecePart:  2
# startLetterLocation : 5
# both letters the samce: t and t
# #####
# another break happend 2
# StartSentecePart:  2
# startLetterLocation : 6
# both letters the samce:   and
# #####
# another break happend 2
# StartSentecePart:  2
# startLetterLocation : 7
# both letters the samce: 1 and 1
# #####
# another break happend 2
# StartSentecePart:  2
# startLetterLocation : 8
# both letters the samce: , and ,
# #####
# another break happend 2
# StartSentecePart:  2
# startLetterLocation : 9
# both letters the samce:   and
# #####
# another break happend 2
# before adding to list StartSentecePart: 3
# StartSentecePart:  3
# startLetterLocation : 0
# startLetterLocation : 1
# both letters the samce: T and T
# #####
# another break happend 2
# StartSentecePart:  3
# startLetterLocation : 2
# both letters the samce: h and h
# #####
# another break happend 2
# StartSentecePart:  3
# startLetterLocation : 3
# both letters the samce: i and i
# #####
# another break happend 2
# StartSentecePart:  3
# startLetterLocation : 4
# both letters the samce: s and s
# #####
# another break happend 2
# StartSentecePart:  4
# startLetterLocation : 0
# startLetterLocation : 1
# both letters the samce:   and
# #####
# another break happend 2
# StartSentecePart:  4
# startLetterLocation : 2
# #####
# StartSentecePart:  5
# startLetterLocation : 0
# startLetterLocation : 1
# startLetterLocation : 2
# both letters the samce: i and i
# #####
# another break happend 2
# StartSentecePart:  5
# startLetterLocation : 3
# both letters the samce: s and s
# #####
# another break happend 2
# StartSentecePart:  5
# startLetterLocation : 4
# both letters the samce:   and
# #####
# another break happend 2
# StartSentecePart:  5
# startLetterLocation : 5
# both letters the samce: p and p
# #####
# another break happend 2
# StartSentecePart:  5
# startLetterLocation : 6
# both letters the samce: a and a
# #####
# another break happend 2
# StartSentecePart:  5
# startLetterLocation : 7
# both letters the samce: r and r
# #####
# another break happend 2
# StartSentecePart:  5
# startLetterLocation : 8
# both letters the samce: t and t
# #####
# another break happend 2
# StartSentecePart:  5
# startLetterLocation : 9
# both letters the samce:   and
# #####
# another break happend 2
# StartSentecePart:  5
# startLetterLocation : 10
# both letters the samce: 2 and 2
# #####
# another break happend 2
# StartSentecePart:  5
# startLetterLocation : 11
# both letters the samce: , and ,
# #####
# another break happend 2
# StartSentecePart:  5
# startLetterLocation : 12
# both letters the samce:   and
# #####
# another break happend 2
# before adding to list StartSentecePart: 6
# StartSentecePart:  6
# startLetterLocation : 0
# startLetterLocation : 1
# both letters the samce: P and P
# #####
# another break happend 2
# StartSentecePart:  6
# startLetterLocation : 2
# both letters the samce: a and a
# #####
# another break happend 2
# StartSentecePart:  6
# startLetterLocation : 3
# both letters the samce: r and r
# #####
# another break happend 2
# StartSentecePart:  6
# startLetterLocation : 4
# both letters the samce: t and t
# #####
# another break happend 2
# StartSentecePart:  7
# startLetterLocation : 0
# startLetterLocation : 1
# startLetterLocation : 2
# #####
# StartSentecePart:  8
# startLetterLocation : 0
# startLetterLocation : 1
# both letters the samce: 3 and 3
# #####
# another break happend 2
# StartSentecePart:  8
# startLetterLocation : 2
# both letters the samce: , and ,
# #####
# another break happend 2
# StartSentecePart:  8
# startLetterLocation : 3
# both letters the samce:   and
# #####
# another break happend 2
# before adding to list StartSentecePart: 9
# StartSentecePart:  9
# startLetterLocation : 0
# startLetterLocation : 1
# both letters the samce: P and P
# #####
# another break happend 2
# StartSentecePart:  9
# startLetterLocation : 2
# both letters the samce: a and a
# #####
# another break happend 2
# StartSentecePart:  9
# startLetterLocation : 3
# both letters the samce: r and r
# #####
# another break happend 2
# StartSentecePart:  10
# startLetterLocation : 0
# startLetterLocation : 1
# #####
# StartSentecePart:  11
# startLetterLocation : 0
# startLetterLocation : 1
# #####
# StartSentecePart:  12
# startLetterLocation : 0
# both letters the samce: t and t
# #####
# another break happend 2
# StartSentecePart:  12
# startLetterLocation : 1
# #####
# StartSentecePart:  13
# startLetterLocation : 0
# startLetterLocation : 1
# both letters the samce:   and
# #####
# another break happend 2
# StartSentecePart:  13
# startLetterLocation : 2
# both letters the samce: 4 and 4
# #####
# another break happend 2
# StartSentecePart:  13
# startLetterLocation : 3
# both letters the samce: . and .
# #####
# another break happend 2
# before adding to list StartSentecePart: 14
# StartSentecePart:  14
# startLetterLocation : 0
# startLetterLocation : 1
# both letters the samce: T and T
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 2
# both letters the samce: h and h
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 3
# both letters the samce: i and i
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 4
# both letters the samce: s and s
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 5
# both letters the samce:   and
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 6
# both letters the samce: i and i
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 7
# both letters the samce: s and s
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 8
# both letters the samce:   and
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 9
# both letters the samce: t and t
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 10
# both letters the samce: h and h
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 11
# both letters the samce: e and e
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 12
# both letters the samce:   and
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 13
# both letters the samce: n and n
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 14
# both letters the samce: e and e
# #####
# another break happend 2
# StartSentecePart:  14
# startLetterLocation : 15
# both letters the samce: w and w
# #####
# another break happend 2
# StartSentecePart:  15
# startLetterLocation : 0
# startLetterLocation : 1
# both letters the samce:   and
# #####
# another break happend 2
# StartSentecePart:  15
# startLetterLocation : 2
# #####
# StartSentecePart:  16
# startLetterLocation : 0
# startLetterLocation : 1
# startLetterLocation : 2
# both letters the samce: P and P
# #####
# StartSentecePart:  16
# startLetterLocation : 3
# both letters the samce: a and a
# #####
# StartSentecePart:  16
# startLetterLocation : 4
# both letters the samce: r and r
# #####
# StartSentecePart:  16
# startLetterLocation : 5
# both letters the samce: a and a
# #####
# StartSentecePart:  16
# startLetterLocation : 6
# both letters the samce: g and g
# #####
# StartSentecePart:  16
# startLetterLocation : 7
# both letters the samce: r and r
# #####
# StartSentecePart:  16
# startLetterLocation : 8
# both letters the samce: a and a
# #####
# StartSentecePart:  16
# startLetterLocation : 9
# both letters the samce: p and p
# #####
# StartSentecePart:  16
# startLetterLocation : 10
# both letters the samce: h and h
# #####
# before adding to list StartSentecePart: 17
# [2, 5, 8, 13, 16]

# %%
valueForFunction[2]
# Out:
# ' part 1, '

# %%
def getRangeChangeList(StartSentecePartList):
    
    RangeList = []
    for i in range(len(StartSentecePartList)):

        HigherRange = StartSentecePartList[i] 

        if i == 0:
            LowerRange = 0
        else:
            LowerRange = StartSentecePartList[i-1] +1

        RangeItem = [LowerRange, HigherRange]

        RangeList.append(RangeItem)


    return RangeList

# %%
getRangeChangeList(StartSentecePartList)
# Out:
# [[0, 2], [3, 5], [6, 8], [9, 13], [14, 16]]

# %%
# OriginalDocument = 'TestDocNoChangeAllBoldArialBlack2.docx'


OriginalDocument = 'DifferentLineText6Changed.docx'

Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'




LocOriginalDocument = Location + OriginalDocument


wordDocument = LocOriginalDocument


document = Document(wordDocument)


item = document.element.xml


soup = BeautifulSoup(item)



responseFind = soup.find('w:sectpr')

stringData = str(responseFind)

# print(stringData)



# pprint.pprint(item)

responseFind2 = soup.find('w:body').findChildren('w:p', recursive=False)



pprint.pprint(responseFind2)

PprParagraphList= []
WrParagraphList= []
for i in responseFind2:
#     print(i)
#     print('=========================================')
    
    
    
    ppr = i.find_all('w:ppr')
    
    PprParagraphList.append(ppr)
    
    Wr = i.find_all('w:r')
    
    if Wr == []:
        pass
    
    else:   
        WrParagraphList.append(Wr)
    
# ### This shows text and text configuration (ex. underline, bold, italic etc)    
# pprint.pprint(WrParagraphList)

# print('===================================')
# print('===================================')
# print('===================================')

# ### this shows spacing
# pprint.pprint(PprParagraphList)
# Out:
# [<w:p w14:paraid="06BB78D6" w14:textid="3F6E1D34" w:rsidr="00E04043" w:rsidrdefault="00882AAF">
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:t>This is</w:t>
# </w:r>
# <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>
# <w:r>
# <w:t xml:space="preserve"> part 1, </w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t>This</w:t>
# </w:r>
# <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> is part 2, </w:t>
# </w:r>
# <w:r>
# <w:t>Part</w:t>
# </w:r>
# <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>
# <w:r>
# <w:t xml:space="preserve">3, </w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Par</w:t>
# </w:r>
# <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> </w:t>
# </w:r>
# <w:prooferr w:type="spellStart"></w:prooferr>
# <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Ÿ</w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>t</w:t>
# </w:r>
# <w:prooferr w:type="spellEnd"></w:prooferr>
# <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> 4.</w:t>
# </w:r>
# </w:p>,
#  <w:p w14:paraid="61174D08" w14:textid="77777777" w:rsidr="00853AE9" w:rsidrdefault="00853AE9">
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# </w:p>,
#  <w:p w14:paraid="55F31AF3" w14:textid="6E6F3B8A" w:rsidr="00853AE9" w:rsidrdefault="00853AE9">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new</w:t>
# </w:r>
# <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>
# <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Paragraph</w:t>
# </w:r>
# </w:p>,
#  <w:p w14:paraid="02825DD5" w14:textid="4A51CA08" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>,
#  <w:p w14:paraid="3EC06DEC" w14:textid="7745C87A" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>,
#  <w:p w14:paraid="4B28F70B" w14:textid="77777777" w:rsidr="00490B75" w:rsidrdefault="00490B75" w:rsidrpr="00CC2CDD">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>]

# %%
print(RangeList)
# Out:
# [[0, 2], [3, 5], [6, 8], [9, 13], [14, 16]]

# %%
NotTheSame = False
for i in range(len(RangeList)):
    
    if NotTheSame:
        print('breakHappened 2')
        break
    
    rangeListItem = RangeList[i]
    
#     print(rangeListItem)
    
    print('===================')
    for i in range(rangeListItem[0], rangeListItem[1] + 1 ):
        if rangeListItem[0] == i:
            compareItem = PprParagraphList[i]
        else:
            print(str(compareItem))
            print('333333333333333333')
            print(str(PprParagraphList[i]))
            print('22222222222222222222222222222222')
            
            if str(compareItem) == str(PprParagraphList[i]):
                
                pass
            else:
                NotTheSame = True
                print('breakHappened 1')
                break
            
if NotTheSame:
    print('NOTtheSame')

else:
    print('SameValues')
# Out:
# ===================
# [<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>]
# 333333333333333333
# [<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>]
# 22222222222222222222222222222222
# [<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>]
# 333333333333333333
# [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>]
# 22222222222222222222222222222222
# breakHappened 1
# breakHappened 2
# NOTtheSame

# %%
WrParagraphList[0][2]
# Out:
# <w:r>
# <w:t xml:space="preserve"> part 1, </w:t>
# </w:r>

# %%
PprParagraphList[1]
# Out:
# [<w:ppr>
#  <w:rpr>
#  <w:i></w:i>
#  </w:rpr>
#  </w:ppr>]

# %%
# OriginalDocument = 'TestDocNoChangeAllBoldArialBlack2.docx'


OriginalDocument = 'DifferentLineText6Changed.docx'

Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'




LocOriginalDocument = Location + OriginalDocument


wordDocument = LocOriginalDocument


document = Document(wordDocument)


item = document.element.xml


soup = BeautifulSoup(item)



responseFind = soup.find('w:sectpr')

stringData = str(responseFind)

# print(stringData)



# pprint.pprint(item)

responseFind2 = soup.find('w:body').findChildren('w:p', recursive=False)



pprint.pprint(responseFind2)

PprParagraphList= []
WrParagraphList= []
for i in responseFind2:
#     print(i)
    print('=========================================')


    
    
    
    ppr = i.find_all('w:ppr')
    
    PprParagraphList.append(ppr)
    
    Wr = i.find_all('w:r')
    
    if Wr == []:
        pass
    
    else:   
        WrParagraphList.append(Wr)
    
### This shows text and text configuration (ex. underline, bold, italic etc)    
pprint.pprint(WrParagraphList)

print('===================================')


print('===================================')
print('===================================')

### this shows spacing
pprint.pprint(PprParagraphList)
# Out:
# [<w:p w14:paraid="06BB78D6" w14:textid="3F6E1D34" w:rsidr="00E04043" w:rsidrdefault="00882AAF">
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:t>This is</w:t>
# </w:r>
# <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>
# <w:r>
# <w:t xml:space="preserve"> part 1, </w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t>This</w:t>
# </w:r>
# <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> is part 2, </w:t>
# </w:r>
# <w:r>
# <w:t>Part</w:t>
# </w:r>
# <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>
# <w:r>
# <w:t xml:space="preserve">3, </w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Par</w:t>
# </w:r>
# <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> </w:t>
# </w:r>
# <w:prooferr w:type="spellStart"></w:prooferr>
# <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Ÿ</w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>t</w:t>
# </w:r>
# <w:prooferr w:type="spellEnd"></w:prooferr>
# <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> 4.</w:t>
# </w:r>
# </w:p>,
#  <w:p w14:paraid="61174D08" w14:textid="77777777" w:rsidr="00853AE9" w:rsidrdefault="00853AE9">
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# </w:p>,
#  <w:p w14:paraid="55F31AF3" w14:textid="6E6F3B8A" w:rsidr="00853AE9" w:rsidrdefault="00853AE9">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new</w:t>
# </w:r>
# <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>
# <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Paragraph</w:t>
# </w:r>
# </w:p>,
#  <w:p w14:paraid="02825DD5" w14:textid="4A51CA08" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>,
#  <w:p w14:paraid="3EC06DEC" w14:textid="7745C87A" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>,
#  <w:p w14:paraid="4B28F70B" w14:textid="77777777" w:rsidr="00490B75" w:rsidrdefault="00490B75" w:rsidrpr="00CC2CDD">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>]
# =========================================
# =========================================
# =========================================
# =========================================
# =========================================
# =========================================
# [[<w:r>
# <w:t>This is</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve"> part 1, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t>This</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> is part 2, </w:t>
# </w:r>,
#   <w:r>
# <w:t>Part</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve">3, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Par</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> </w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>t</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> 4.</w:t>
# </w:r>],
#  [<w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Paragraph</w:t>
# </w:r>]]
# ===================================
# ===================================
# ===================================
# [[<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>]]

# %%
wrList = []
for i in responseFind2:
#     print(i)
#     print('=========================================')

    wr = i.find_all('w:r')
    
    wrList.append(wr)
    
    
pprint.pprint(wrList)
# Out:
# [[<w:r>
# <w:t>This is</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve"> part 1, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t>This</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> is part 2, </w:t>
# </w:r>,
#   <w:r>
# <w:t>Part</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve">3, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Par</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> </w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>t</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> 4.</w:t>
# </w:r>],
#  [],
#  [<w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Paragraph</w:t>
# </w:r>],
#  [],
#  [],
#  []]

# %%
pprint.pprint(wrList[0][5])
# Out:
# <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> is part 2, </w:t>
# </w:r>

# %%
pprint.pprint(WrParagraphList)
# Out:
# [[<w:r>
# <w:t>This is</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve"> part 1, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t>This</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> is part 2, </w:t>
# </w:r>,
#   <w:r>
# <w:t>Part</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve">3, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Par</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> </w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>t</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> 4.</w:t>
# </w:r>],
#  [<w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Paragraph</w:t>
# </w:r>]]

# %%
WrParagraphList[0][3]
# Out:
# <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t>This</w:t>
# </w:r>

# %%
WrParagraphList[0][3].find('w:rpr')
# Out:
# <w:rpr>
# <w:b></w:b>
# </w:rpr>

# %%
rprItemList = []
for x in range(len(WrParagraphList)):
    checkedItem = WrParagraphList[x]
        
    for t in range(len(checkedItem)):
        checkedItemPart = checkedItem[t]

        rprItem = checkedItemPart.find('w:rpr')

        rprItemList.append(rprItem)
        
        
        

pprint.pprint(rprItemList)
# Out:
# [None,
#  None,
#  None,
#  <w:rpr>
# <w:b></w:b>
# </w:rpr>,
#  <w:rpr>
# <w:b></w:b>
# </w:rpr>,
#  <w:rpr>
# <w:b></w:b>
# </w:rpr>,
#  None,
#  None,
#  None,
#  <w:rpr>
# <w:i></w:i>
# </w:rpr>,
#  <w:rpr>
# <w:i></w:i>
# </w:rpr>,
#  <w:rpr>
# <w:i></w:i>
# </w:rpr>,
#  <w:rpr>
# <w:i></w:i>
# </w:rpr>,
#  <w:rpr>
# <w:i></w:i>
# </w:rpr>,
#  <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>,
#  <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>,
#  <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>]

# %%
######## this is for checking if the words even though having a controlled additin were not altered by things like 
######## if its bold or italic or underlined, etc.



NotTheSame = False
for i in range(len(RangeList)):
    
    if NotTheSame:
        print('breakHappened 2')
        break
    
    rangeListItem = RangeList[i]
    
#     print(rangeListItem)
    
    print('===================')
    for i in range(rangeListItem[0], rangeListItem[1] + 1 ):
        if rangeListItem[0] == i:
            compareItem = rprItemList[i]
        else:
            print(str(compareItem))
            print('333333333333333333')
            print(str(rprItemList[i]))
            print('22222222222222222222222222222222')
            
            if str(compareItem) == str(rprItemList[i]):
                
                pass
            else:
                NotTheSame = True
                print('breakHappened 1')
                break
            
if NotTheSame:
    print('NOTtheSame')

else:
    print('SameValues')
# Out:
# ===================
# None
# 333333333333333333
# None
# 22222222222222222222222222222222
# None
# 333333333333333333
# None
# 22222222222222222222222222222222
# ===================
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# 333333333333333333
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# 22222222222222222222222222222222
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# 333333333333333333
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# 22222222222222222222222222222222
# ===================
# None
# 333333333333333333
# None
# 22222222222222222222222222222222
# None
# 333333333333333333
# None
# 22222222222222222222222222222222
# ===================
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# 333333333333333333
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# 22222222222222222222222222222222
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# 333333333333333333
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# 22222222222222222222222222222222
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# 333333333333333333
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# 22222222222222222222222222222222
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# 333333333333333333
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# 22222222222222222222222222222222
# ===================
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# 333333333333333333
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# 22222222222222222222222222222222
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# 333333333333333333
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# 22222222222222222222222222222222
# SameValues

# %%
# this is to get the original text data information

##### this is all the steps to get the page general settings

from docx import Document

from bs4 import BeautifulSoup

import pprint



def getParagraphData(Location, DocumentName):

    LocOriginalDocument = Location + DocumentName

    document = Document(LocOriginalDocument)

    item = document.element.xml

    soup = BeautifulSoup(item)


    responseFind = soup.find('w:sectpr')

    sectData = str(responseFind)

    responseFind2 = soup.find('w:body').findChildren('w:p', recursive=False)

    PprParagraphList= []
    WrParagraphList= []
    for i in responseFind2:

        ppr = i.find_all('w:ppr')    
        PprParagraphList.append(ppr)

        Wr = i.find_all('w:r')    
        if Wr == []:
            pass

        else:   
            WrParagraphList.append(Wr)


    return WrParagraphList, PprParagraphList, sectData

# %%
# DocumentName = 'TestDocNoChangeAllBoldArialBlack2.docx'


DocumentName = 'DifferentLineText6Changed.docx'

Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'


pprint.pprint(getParagraphData(Location, DocumentName))
# Out:
# ([[<w:r>
# <w:t>This is</w:t>
# </w:r>,
#    <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#    <w:r>
# <w:t xml:space="preserve"> part 1, </w:t>
# </w:r>,
#    <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t>This</w:t>
# </w:r>,
#    <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#    <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> is part 2, </w:t>
# </w:r>,
#    <w:r>
# <w:t>Part</w:t>
# </w:r>,
#    <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#    <w:r>
# <w:t xml:space="preserve">3, </w:t>
# </w:r>,
#    <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Par</w:t>
# </w:r>,
#    <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> </w:t>
# </w:r>,
#    <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Ÿ</w:t>
# </w:r>,
#    <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>t</w:t>
# </w:r>,
#    <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> 4.</w:t>
# </w:r>],
#   [<w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new</w:t>
# </w:r>,
#    <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#    <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Paragraph</w:t>
# </w:r>]],
#  [[<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#   [<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#   [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#   [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#   [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#   [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>]],
#  '<w:sectpr w:rsidr="00490B75" w:rsidrpr="00CC2CDD">\n'
#  '<w:pgsz w:h="15840" w:w="12240"></w:pgsz>\n'
#  '<w:pgmar w:bottom="1440" w:footer="720" w:gutter="0" w:header="720" '
#  'w:left="1440" w:right="1440" w:top="1440"></w:pgmar>\n'
#  '<w:cols w:space="720"></w:cols>\n'
#  '<w:docgrid w:linepitch="360"></w:docgrid>\n'
#  '</w:sectpr>')

# %%
OriginalDocument = 'DifferentLineText6Changed.docx'

Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'


Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'
DocumentName = 'DifferentLineText6Changed.docx'


Location2 = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'
DocumentName2 = 'DifferentLineText6.docx'




WrParagraphList, PprParagraphList, sectData = getParagraphData(Location, DocumentName)


Location = Location2
DocumentName = DocumentName2 


WrParagraphList2, PprParagraphList2, sectData2 = getParagraphData(Location, DocumentName)

# %%
import pprint


print('WrParagraphList: ')
pprint.pprint(WrParagraphList) 
print('...........................')

print('PprParagraphList: ')
pprint.pprint(PprParagraphList)

print('...........................')
print('sectData: ')
pprint.pprint(sectData)

print('===========================================')
print('WrParagraphList2: ')
pprint.pprint(WrParagraphList2) 

print('...........................')
print('PprParagraphList2: ')
pprint.pprint(PprParagraphList2)

print('...........................')
print('sectData2: ')
pprint.pprint(sectData2)
# Out:
# WrParagraphList:
# [[<w:r>
# <w:t>This is</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve"> part 1, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t>This</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> is part 2, </w:t>
# </w:r>,
#   <w:r>
# <w:t>Part</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve">3, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Par</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> </w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>t</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> 4.</w:t>
# </w:r>],
#  [<w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Paragraph</w:t>
# </w:r>]]
# ...........................
# PprParagraphList:
# [[<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>]]
# ...........................
# sectData:
# ('<w:sectpr w:rsidr="00490B75" w:rsidrpr="00CC2CDD">\n'
#  '<w:pgsz w:h="15840" w:w="12240"></w:pgsz>\n'
#  '<w:pgmar w:bottom="1440" w:footer="720" w:gutter="0" w:header="720" '
#  'w:left="1440" w:right="1440" w:top="1440"></w:pgmar>\n'
#  '<w:cols w:space="720"></w:cols>\n'
#  '<w:docgrid w:linepitch="360"></w:docgrid>\n'
#  '</w:sectpr>')
# ===========================================
# WrParagraphList2:
# [[<w:r>
# <w:t xml:space="preserve">This is part 1, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve">This is part 2, </w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve">Part3, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Part 4.</w:t>
# </w:r>],
#  [<w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new Paragraph</w:t>
# </w:r>]]
# ...........................
# PprParagraphList2:
# [[<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>]]
# ...........................
# sectData2:
# ('<w:sectpr w:rsidr="00490B75" w:rsidrpr="00CC2CDD">\n'
#  '<w:pgsz w:h="15840" w:w="12240"></w:pgsz>\n'
#  '<w:pgmar w:bottom="1440" w:footer="720" w:gutter="0" w:header="720" '
#  'w:left="1440" w:right="1440" w:top="1440"></w:pgmar>\n'
#  '<w:cols w:space="720"></w:cols>\n'
#  '<w:docgrid w:linepitch="360"></w:docgrid>\n'
#  '</w:sectpr>')

# %%
def CompareSectData(sectData, sectData2):
    if sectData == sectData2:
        return 'sectDataIsSame'
    else:
        return 'sectDataNOTsame'

# %%
CompareSectData(sectData, sectData2)
# Out:
# 'sectDataIsSame'

# %%
def ComparePprParagraphList(PprParagraphList, PprParagraphList2):
    if PprParagraphList == PprParagraphList2:
        return 'PprParagraphListIsSame'
    else:
        return 'PprParagraphListNOTsame'

# %%
ComparePprParagraphList(PprParagraphList, PprParagraphList2)
# Out:
# 'PprParagraphListIsSame'

# %%
    
    
def getwtValueList(WrParagraphList):
    
    wtValueListText = ''
    wtValueList = []
    for Paragraph in WrParagraphList:

        for item in Paragraph:

            wtValue = item.find('w:t')

            if wtValue == None:
                wtValue = ''
            else:
                pass

            wtValueList.append(wtValue.text)
            wtValueListText = wtValueListText + wtValue.text
    
    ValueInText = False
    if 'Ÿ' in wtValueListText:
        ValueInText = True

    wtValueListText = wtValueListText.replace(" Ÿ", "")
    wtValueListText = wtValueListText.replace("Ÿ", "")

    
    return wtValueList , wtValueListText, ValueInText

# %%
wtValueList , wtValueListText, ValueInText = getwtValueList(WrParagraphList)





wtValueList2 , wtValueListText2, ValueInText2 = getwtValueList(WrParagraphList2)

# %%
print('wtValueList: ') 
pprint.pprint(wtValueList)


print('....................')
print('wtValueListText: ') 
pprint.pprint(wtValueListText)

print('....................')
print('ValueInText: ')
pprint.pprint(ValueInText)

print('===============================')
print('wtValueList2: ')
pprint.pprint(wtValueList2)

print('....................')
print('wtValueListText2: ') 
pprint.pprint(wtValueListText2)

print('....................')
print('ValueInText2: ')
pprint.pprint(ValueInText2)
# Out:
# wtValueList:
# ['This is',
#  ' Ÿ',
#  ' part 1, ',
#  'This',
#  ' Ÿ',
#  ' is part 2, ',
#  'Part',
#  ' Ÿ',
#  '3, ',
#  'Par',
#  ' ',
#  'Ÿ',
#  't',
#  ' 4.',
#  'This is the new',
#  ' Ÿ',
#  ' Paragraph']
# ....................
# wtValueListText:
# 'This is part 1, This is part 2, Part3, Part 4.This is the new Paragraph'
# ....................
# ValueInText:
# True
# ===============================
# wtValueList2:
# ['This is part 1, ',
#  'This is part 2, ',
#  'Part3, ',
#  'Part 4.',
#  'This is the new Paragraph']
# ....................
# wtValueListText2:
# 'This is part 1, This is part 2, Part3, Part 4.This is the new Paragraph'
# ....................
# ValueInText2:
# False

# %%
def isTextSame(wtValueListText, wtValueListText2):
    
    if wtValueListText == wtValueListText:
        return 'TextIsSame'
    else:
        return 'TextNOTsame'

# %%
def OrderCorrectlyWtValues(wtValueList, wtValueList2):

    if str(wtValueList) == str(wtValueList2):
#         print("they are equal")

        checkValue = '2'
        valueForFunction = wtValueList
        valueForFunctionLess = wtValueList2

    else:
        checkValue='-1'
        if len(wtValueList)> len(wtValueList2):
#             print('wtValueList is greater')

            checkValue = '0'
            valueForFunction = wtValueList
            valueForFunctionLess = wtValueList2
        else:
#             print('wtValueList2 is greater')

            checkValue = '1'
            valueForFunction = wtValueList2
            valueForFunctionLess = wtValueList

    return checkValue, valueForFunction , valueForFunctionLess

# %%
checkValue, valueForFunction , valueForFunctionLess = OrderCorrectlyWtValues(wtValueList, wtValueList2)

# %%
print('checkValue: ')
pprint.pprint(checkValue)

print('...................')
print('valueForFunction: ')
pprint.pprint(valueForFunction)

print('...................')
print('valueForFunctionLess: ')
pprint.pprint(valueForFunctionLess)
# Out:
# checkValue:
# '0'
# ...................
# valueForFunction:
# ['This is',
#  ' Ÿ',
#  ' part 1, ',
#  'This',
#  ' Ÿ',
#  ' is part 2, ',
#  'Part',
#  ' Ÿ',
#  '3, ',
#  'Par',
#  ' ',
#  'Ÿ',
#  't',
#  ' 4.',
#  'This is the new',
#  ' Ÿ',
#  ' Paragraph']
# ...................
# valueForFunctionLess:
# ['This is part 1, ',
#  'This is part 2, ',
#  'Part3, ',
#  'Part 4.',
#  'This is the new Paragraph']

# %%
getwtValueList(WrParagraphList)
# Out:
# (['This is',
#   ' Ÿ',
#   ' part 1, ',
#   'This',
#   ' Ÿ',
#   ' is part 2, ',
#   'Part',
#   ' Ÿ',
#   '3, ',
#   'Par',
#   ' ',
#   'Ÿ',
#   't',
#   ' 4.',
#   'This is the new',
#   ' Ÿ',
#   ' Paragraph'],
#  'This is part 1, This is part 2, Part3, Part 4.This is the new Paragraph',
#  True)

# %%
def getStartSentecePartList(valueForFunctionLess, valueForFunction):

    StartSentecePartList = []
    StartSentecePart = -1
    NumberOfSentecePartsList = []
    for i in range(len(valueForFunctionLess)):

        item = valueForFunctionLess[i]

        startLetterLocation = -1    
        for l in range(len(item)):

            letter = item[l]

            breakHappend = False
            for x in range(StartSentecePart, len(valueForFunction)):

                if breakHappend:
                    break

                senteceTocheck = valueForFunction[x]            

                for z in range(startLetterLocation , len(senteceTocheck)):

                    if breakHappend:
                        print('another break happend')
                        break                    

                    startLetterLocation  = startLetterLocation  + 1

                    leterToCheck = senteceTocheck[z]

                    if z == len(senteceTocheck) -1 :
                        startLetterLocation = -1
                        StartSentecePart = StartSentecePart + 1

                    if leterToCheck == letter:                   
                        NumberOfSentecePartsList.append(StartSentecePart)                
                        breakHappend = True
                        break


        StartSentecePartList.append(StartSentecePart - 1)     

        
    return StartSentecePartList

# %%
StartSentecePartList = getStartSentecePartList(valueForFunctionLess, valueForFunction)

# %%
print('StartSentecePartList: ')
print(StartSentecePartList)
# Out:
# StartSentecePartList:
# [2, 5, 8, 13, 16]

# %%
def getRangeChangeList(StartSentecePartList):
    
    RangeList = []
    for i in range(len(StartSentecePartList)):

        HigherRange = StartSentecePartList[i] 

        if i == 0:
            LowerRange = 0
        else:
            LowerRange = StartSentecePartList[i-1] +1

        RangeItem = [LowerRange, HigherRange]

        RangeList.append(RangeItem)


    return RangeList

# %%
RangeList = getRangeChangeList(StartSentecePartList)

# %%
print('RangeList: ')
print(RangeList)
# Out:
# RangeList:
# [[0, 2], [3, 5], [6, 8], [9, 13], [14, 16]]

# %%
######## this is for checking if the words even though having a controlled additin were not altered by things like 
######## if its bold or italic or underlined, etc.


def CheckforItalicBoldAlteration(RangeList, WrParagraphList):
       
    rprItemList = []
    for x in range(len(WrParagraphList)):
        checkedItem = WrParagraphList[x]

        for t in range(len(checkedItem)):
            checkedItemPart = checkedItem[t]

            rprItem = checkedItemPart.find('w:rpr')

            rprItemList.append(rprItem)
        

    NotTheSame = False
    for i in range(len(RangeList)):

        if NotTheSame:
            break

        rangeListItem = RangeList[i]

        for i in range(rangeListItem[0], rangeListItem[1] + 1 ):
            if rangeListItem[0] == i:
                compareItem = rprItemList[i]
                
            else:
                if str(compareItem) == str(rprItemList[i]):
                    pass
                
                else:
                    NotTheSame = True
                    break

    if NotTheSame:
        return 'NOTtheSame'

    else:
        return 'SameValues'

# %%
CheckforItalicBoldAlteration(RangeList, WrParagraphList)
# Out:
# 'SameValues'

# %%
pprint.pprint(WrParagraphList)
# Out:
# [[<w:r>
# <w:t>This is</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve"> part 1, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t>This</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve"> is part 2, </w:t>
# </w:r>,
#   <w:r>
# <w:t>Part</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve">3, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Par</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> </w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Ÿ</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>t</w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t xml:space="preserve"> 4.</w:t>
# </w:r>],
#  [<w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new</w:t>
# </w:r>,
#   <w:r w:rsidr="00AC1854" w:rsidrpr="00AC1854">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Ÿ</w:t>
# </w:r>,
#   <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t xml:space="preserve"> Paragraph</w:t>
# </w:r>]]
