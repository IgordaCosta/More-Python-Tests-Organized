# %%
ListUsed = [[['0.0.1', '0.0.9'],
  ['0.1.2', '0.1.9'],
  ['0.2.0', '0.2.3', '0.2.4', '0.2.7', '0.2.8', '0.2.9'],
  ['0.3.2', '0.3.5', '0.3.6', '0.3.9']],
 [['1.0.1', '1.0.9'],
  ['1.1.2', '1.1.9'],
  ['1.2.0', '1.2.3', '1.2.4', '1.2.7', '1.2.8', '1.2.9'],
  ['1.3.2', '1.3.5', '1.3.6', '1.3.9']],
 [['2.0.2', '2.0.9'],
  ['2.1.2', '2.1.9'],
  ['2.2.0', '2.2.3', '2.2.4', '2.2.7', '2.2.8', '2.2.9'],
  ['2.3.1', '2.3.5', '2.3.6', '2.3.9']],
 [['3.0.0', '3.0.1', '3.0.2', '3.0.3'],
  ['3.1.0', '3.1.1', '3.1.2', '3.1.3'],
  ['3.2.0', '3.2.1', '3.2.2', '3.2.3'],
  ['3.3.0', '3.3.1', '3.3.2', '3.3.3'],
  ['3.4.0', '3.4.1', '3.4.2', '3.4.3'],
  ['3.5.0', '3.5.1', '3.5.2', '3.5.3']],
 [['4.0.2', '4.0.9'],
  ['4.1.2', '4.1.9'],
  ['4.2.0', '4.2.3', '4.2.4', '4.2.7', '4.2.8', '4.2.9'],
  ['4.3.1', '4.3.5', '4.3.6', '4.3.9']],
 [['5.0.0', '5.0.1', '5.0.2', '5.0.3'],
  ['5.1.0', '5.1.1', '5.1.2', '5.1.3'],
  ['5.2.0', '5.2.1', '5.2.2', '5.2.3'],
  ['5.3.0', '5.3.1', '5.3.2', '5.3.3'],
  ['5.4.0', '5.4.1', '5.4.2', '5.4.3'],
  ['5.5.0', '5.5.1', '5.5.2', '5.5.3']],
 [['6.0.0', '6.0.1', '6.0.2', '6.0.3', '6.0.4'],
  ['6.1.0', '6.1.1', '6.1.2', '6.1.3', '6.1.4'],
  ['6.2.0', '6.2.1', '6.2.2', '6.2.3', '6.2.4'],
  ['6.3.0', '6.3.1', '6.3.2', '6.3.3', '6.3.4'],
  ['6.4.0', '6.4.1', '6.4.2', '6.4.3', '6.4.4'],
  ['6.5.0', '6.5.1', '6.5.2', '6.5.3', '6.5.4']]]
  
  
  
print(ListUsed)
# Out:
# [[['0.0.1', '0.0.9'], ['0.1.2', '0.1.9'], ['0.2.0', '0.2.3', '0.2.4', '0.2.7', '0.2.8', '0.2.9'], ['0.3.2', '0.3.5', '0.3.6', '0.3.9']], [['1.0.1', '1.0.9'], ['1.1.2', '1.1.9'], ['1.2.0', '1.2.3', '1.2.4', '1.2.7', '1.2.8', '1.2.9'], ['1.3.2', '1.3.5', '1.3.6', '1.3.9']], [['2.0.2', '2.0.9'], ['2.1.2', '2.1.9'], ['2.2.0', '2.2.3', '2.2.4', '2.2.7', '2.2.8', '2.2.9'], ['2.3.1', '2.3.5', '2.3.6', '2.3.9']], [['3.0.0', '3.0.1', '3.0.2', '3.0.3'], ['3.1.0', '3.1.1', '3.1.2', '3.1.3'], ['3.2.0', '3.2.1', '3.2.2', '3.2.3'], ['3.3.0', '3.3.1', '3.3.2', '3.3.3'], ['3.4.0', '3.4.1', '3.4.2', '3.4.3'], ['3.5.0', '3.5.1', '3.5.2', '3.5.3']], [['4.0.2', '4.0.9'], ['4.1.2', '4.1.9'], ['4.2.0', '4.2.3', '4.2.4', '4.2.7', '4.2.8', '4.2.9'], ['4.3.1', '4.3.5', '4.3.6', '4.3.9']], [['5.0.0', '5.0.1', '5.0.2', '5.0.3'], ['5.1.0', '5.1.1', '5.1.2', '5.1.3'], ['5.2.0', '5.2.1', '5.2.2', '5.2.3'], ['5.3.0', '5.3.1', '5.3.2', '5.3.3'], ['5.4.0', '5.4.1', '5.4.2', '5.4.3'], ['5.5.0', '5.5.1', '5.5.2', '5.5
# ...

# %%
print(type(ListUsed[0][0][0]) == type([]))
# Out:
# False

# %%
print(len(ListUsed))

print(len(ListUsed[0]))

print(len(ListUsed[0][0]))



# for itemz in ListUsed[0][0][]
#     for itemz in ListUsed[itemx][itemy][itemz]
# Out:
# 7
# 4
# 2

# %%
ItemList = []
for itemX in ListUsed:
    for itemY in itemX:
        for item in itemY:
            ItemList.append(item)
            
print(ItemList)
# Out:
# ['0.0.1', '0.0.9', '0.1.2', '0.1.9', '0.2.0', '0.2.3', '0.2.4', '0.2.7', '0.2.8', '0.2.9', '0.3.2', '0.3.5', '0.3.6', '0.3.9', '1.0.1', '1.0.9', '1.1.2', '1.1.9', '1.2.0', '1.2.3', '1.2.4', '1.2.7', '1.2.8', '1.2.9', '1.3.2', '1.3.5', '1.3.6', '1.3.9', '2.0.2', '2.0.9', '2.1.2', '2.1.9', '2.2.0', '2.2.3', '2.2.4', '2.2.7', '2.2.8', '2.2.9', '2.3.1', '2.3.5', '2.3.6', '2.3.9', '3.0.0', '3.0.1', '3.0.2', '3.0.3', '3.1.0', '3.1.1', '3.1.2', '3.1.3', '3.2.0', '3.2.1', '3.2.2', '3.2.3', '3.3.0', '3.3.1', '3.3.2', '3.3.3', '3.4.0', '3.4.1', '3.4.2', '3.4.3', '3.5.0', '3.5.1', '3.5.2', '3.5.3', '4.0.2', '4.0.9', '4.1.2', '4.1.9', '4.2.0', '4.2.3', '4.2.4', '4.2.7', '4.2.8', '4.2.9', '4.3.1', '4.3.5', '4.3.6', '4.3.9', '5.0.0', '5.0.1', '5.0.2', '5.0.3', '5.1.0', '5.1.1', '5.1.2', '5.1.3', '5.2.0', '5.2.1', '5.2.2', '5.2.3', '5.3.0', '5.3.1', '5.3.2', '5.3.3', '5.4.0', '5.4.1', '5.4.2', '5.4.3', '5.5.0', '5.5.1', '5.5.2', '5.5.3', '6.0.0', '6.0.1', '6.0.2', '6.0.3', '6.0.4', '6.1.0', '6.1.1'
# ...

# %%
print(len(ItemList))
# Out:
# 134

# %%
list2 = ['0.0.1', '0.0.9', '0.1.2', '0.1.9', '0.2.0', '0.2.3', '0.2.4', '0.2.7', '0.2.8', '0.2.9', '0.3.2', '0.3.5', '0.3.6', '0.3.9','1.0.1', '1.0.9', '1.1.2', '1.1.9', '1.2.0', '1.2.3', '1.2.4', '1.2.7', '1.2.8', '1.2.9', '1.3.2', '1.3.5', '1.3.6', '1.3.9','2.0.2', '2.0.9', '2.1.2', '2.1.9', '2.2.0', '2.2.3', '2.2.4', '2.2.7', '2.2.8', '2.2.9', '2.3.1', '2.3.5', '2.3.6', '2.3.9','3.0.0', '3.0.1', '3.0.2', '3.0.3', '3.1.0', '3.1.1', '3.1.2', '3.1.3', '3.2.0', '3.2.1', '3.2.2', '3.2.3', '3.3.0', '3.3.1', '3.3.2', '3.3.3', '3.4.0', '3.4.1', '3.4.2', '3.4.3', '3.5.0', '3.5.1', '3.5.2', '3.5.3','4.0.2', '4.0.9', '4.1.2', '4.1.9', '4.2.0', '4.2.3', '4.2.4', '4.2.7', '4.2.8', '4.2.9', '4.3.1', '4.3.5', '4.3.6', '4.3.9','5.0.0', '5.0.1', '5.0.2', '5.0.3', '5.1.0', '5.1.1', '5.1.2', '5.1.3', '5.2.0', '5.2.1', '5.2.2', '5.2.3', '5.3.0', '5.3.1', '5.3.2', '5.3.3', '5.4.0', '5.4.1', '5.4.2', '5.4.3', '5.5.0', '5.5.1', '5.5.2', '5.5.3','6.0.0', '6.0.1', '6.0.2', '6.0.3', '6.0.4', '6.1.0', '6.1.1', '6.1.2', '6.1.3', '6.1.4', '6.2.0', '6.2.1', '6.2.2', '6.2.3', '6.2.4', '6.3.0', '6.3.1', '6.3.2', '6.3.3', '6.3.4', '6.4.0', '6.4.1', '6.4.2', '6.4.3', '6.4.4', '6.5.0', '6.5.1', '6.5.2', '6.5.3', '6.5.4']

print(len(list2))
# Out:
# 134

# %%
print('0.0.9' in list2)
# Out:
# True

# %%
tableValues = ['0.0.9.17.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.0.9.57.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.0.9.81.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.0.9.103.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.0.9.134.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.0.9.160.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.0.9.169.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.1.9.0.1', '0.2.3.0.1', '0.2.7.0.1', '0.2.9.0.1', '0.3.2.2.17.0.2.0.9.0.10.0.13', '0.3.2.9.17.0.2.0.9.0.10.0.13', '0.3.2.10.17.0.2.0.9.0.10.0.13', '0.3.2.13.17.0.2.0.9.0.10.0.13', '0.3.5.0.1', '0.3.9.0.1', '1.0.9.0.1', '1.1.9.0.1', '6.0.0.0.1', '6.4.4.0.1']



print(len(tableValues))
# Out:
# 21

# %%
import pprint


pprint.pprint(tableValues)
# Out:
# ['0.0.9.17.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0',
#  '0.0.9.57.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0',
#  '0.0.9.81.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0',
#  '0.0.9.103.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0',
#  '0.0.9.134.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0',
#  '0.0.9.160.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0',
#  '0.0.9.169.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0',
#  '0.1.9.0.1',
#  '0.2.3.0.1',
#  '0.2.7.0.1',
#  '0.2.9.0.1',
#  '0.3.2.2.17.0.2.0.9.0.10.0.13',
#  '0.3.2.9.17.0.2.0.9.0.10.0.13',
#  '0.3.2.10.17.0.2.0.9.0.10.0.13',
#  '0.3.2.13.17.0.2.0.9.0.10.0.13',
#  '0.3.5.0.1',
#  '0.3.9.0.1',
#  '1.0.9.0.1',
#  '1.1.9.0.1',
#  '6.0.0.0.1',
#  '6.4.4.0.1']

# %%
print(len(tableValues))
# Out:
# 21

# %%
firstFewTable = ['0.0.9.17.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.0.9.57.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.0.9.81.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.0.9.103.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.0.9.134.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.0.9.160.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.0.9.169.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0']



print(len(firstFewTable))
# Out:
# 7

# %%
item = '0.17.2.25.2.49.2.71.2.102.2.128.3.0'.split('.')

print(len(item)/2)
# Out:
# 7.0

# %%
###### from it can be seen above it is adding one of this items por location on the paragraph
###### it should only be adding one for simplisity

# %%
tableValues2  =  ['0.0.9.17.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0', '0.1.9.0.1', '0.2.3.0.1', '0.2.7.0.1', '0.2.9.0.1', '0.3.2.2.17.0.2.0.9.0.10.0.13', '0.3.5.0.1', '0.3.9.0.1', '1.0.9.0.1', '1.1.9.0.1', '6.0.0.0.1', '6.4.4.0.1']

# %%
pprint.pprint(tableValues2)
# Out:
# ['0.0.9.17.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0',
#  '0.1.9.0.1',
#  '0.2.3.0.1',
#  '0.2.7.0.1',
#  '0.2.9.0.1',
#  '0.3.2.2.17.0.2.0.9.0.10.0.13',
#  '0.3.5.0.1',
#  '0.3.9.0.1',
#  '1.0.9.0.1',
#  '1.1.9.0.1',
#  '6.0.0.0.1',
#  '6.4.4.0.1']

# %%
print(len(tableValues2))
# Out:
# 12

# %%
tableValues3 = ['0.0.9.17.170.0.17.2.25.2.49.2.71.2.102.2.128.3.0',

 '0.1.9.0.1',
 '0.2.3.0.1',
 '0.2.7.0.1',
 '0.2.9.0.1',
 '0.3.2.2.17.0.2.0.9.0.10.0.13',
 
 '0.3.5.0.1',
 '0.3.9.0.1',
 '1.0.9.0.1',
 '1.1.9.0.1',
 '6.0.0.0.1',
 '6.4.4.0.1']

# %%
print(len(tableValues3))
# Out:
# 12
