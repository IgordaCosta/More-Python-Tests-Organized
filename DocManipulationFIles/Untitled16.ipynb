# %%
##### this deletes all the markers then checks if there are other changes to the document besides the markers
##### this changes can be text or font style or page style
##### if there are changes to the document the retun message will say so
##### if ther are NO changes the return message will say that instead



OriginalDocument = 'TestDocNoChangeAllBoldArialBlack2.docx'

DocumentWithMarkers = 'TestChanged13.docx'

Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'


wordDocument = r'C:\Users\IgorDC\Desktop\PydocTest\TestDocNoChangeAllBoldArialBlack2.docx'




LocOriginalDocument = Location + OriginalDocument

LocDocumentWithMarkers = Location + DocumentWithMarkers

# %%
from docx import Document
import pprint

# import UserImputToTableImput
import closeWord



wordDocument = LocOriginalDocument


document = Document(wordDocument)
# help(document.settings.element.xml)

# print(document.sections[0].__dict__)

pprint.pprint(document.element.xml)
# Out:
# ('<w:document '
#  'xmlns:wpc="http://schemas.microsoft.com/office/word/2010/wordprocessingCanvas" '
#  'xmlns:cx="http://schemas.microsoft.com/office/drawing/2014/chartex" '
#  'xmlns:cx1="http://schemas.microsoft.com/office/drawing/2015/9/8/chartex" '
#  'xmlns:cx2="http://schemas.microsoft.com/office/drawing/2015/10/21/chartex" '
#  'xmlns:cx3="http://schemas.microsoft.com/office/drawing/2016/5/9/chartex" '
#  'xmlns:cx4="http://schemas.microsoft.com/office/drawing/2016/5/10/chartex" '
#  'xmlns:cx5="http://schemas.microsoft.com/office/drawing/2016/5/11/chartex" '
#  'xmlns:cx6="http://schemas.microsoft.com/office/drawing/2016/5/12/chartex" '
#  'xmlns:cx7="http://schemas.microsoft.com/office/drawing/2016/5/13/chartex" '
#  'xmlns:cx8="http://schemas.microsoft.com/office/drawing/2016/5/14/chartex" '
#  'xmlns:mc="http://schemas.openxmlformats.org/markup-compatibility/2006" '
#  'xmlns:aink="http://schemas.microsoft.com/office/drawing/2016/ink" '
#  'xmlns:am3d="http://schemas.microsoft.com/office/drawing/2017/model3d" '
#  'xmlns:o="urn:schemas-microsoft-com:office:office" '
#  'xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships" '
#  'xmlns:m="http://schemas.openxmlformats.org/officeDocument/2006/math" '
#  'xmlns:v="urn:schemas-microsoft-com:vml" '
#  'xmlns:wp14="http://schemas.microsoft.com/office/word/2010/wordprocessingDrawing" '
#  'xmlns:wp="http://schemas.openxmlformats.org/drawingml/2006/wordprocessingDrawing" '
#  'xmlns:w10="urn:schemas-microsoft-com:office:word" '
#  'xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" '
#  'xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml" '
#  'xmlns:w15="http://schemas.microsoft.com/office/word/2012/wordml" '
#  'xmlns:w16cid="http://schemas.microsoft.com/office/word/2016/wordml/cid" '
#  'xmlns:w16se="http://schemas.microsoft.com/office/word/2015/wordml/symex" '
#  'xmlns:wpg="http://schemas.microsoft.com/office/word/2010/wordprocessingGroup" '
#  'xmlns:wpi="http://schemas.microsoft.com/office/word/2010/wordprocessingInk" '
#  'xmlns:wne="http://schemas.microsoft.com/office/word/2006/wordml" '
#  'xmlns:wps="http://schemas.microsoft.com/office/word/2010/wordprocessingShape" '
#  'mc:Ignorable="w14 w15 w16se w16cid wp14">\n'
#  '  <w:body>\n'
#  '    <w:p w14:paraId="4A5DE398" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="00D06DEA">\n'
#  '      <w:pPr>\n'
#  '        <w:pStyle w:val="Heading1"/>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:bCs/>\n'
#  '          <w:noProof/>\n'
#  '        </w:rPr>\n'
#  '        <w:drawing>\n'
#  '          <wp:inline distT="0" distB="0" distL="0" distR="0" '
#  'wp14:anchorId="53B36FF5" wp14:editId="25DAEE7C">\n'
#  '            <wp:extent cx="2133600" cy="457200"/>\n'
#  '            <wp:effectExtent l="0" t="0" r="0" b="0"/>\n'
#  '            <wp:docPr id="1" name="Picture 1">\n'
#  '              <a:hlinkClick '
#  'xmlns:a="http://schemas.openxmlformats.org/drawingml/2006/main" '
#  'r:id="rId5"/>\n'
#  '            </wp:docPr>\n'
#  '            <wp:cNvGraphicFramePr>\n'
#  '              <a:graphicFrameLocks '
#  'xmlns:a="http://schemas.openxmlformats.org/drawingml/2006/main" '
#  'noChangeAspect="1"/>\n'
#  '            </wp:cNvGraphicFramePr>\n'
#  '            <a:graphic '
#  'xmlns:a="http://schemas.openxmlformats.org/drawingml/2006/main">\n'
#  '              <a:graphicData '
#  'uri="http://schemas.openxmlformats.org/drawingml/2006/picture">\n'
#  '                <pic:pic '
#  'xmlns:pic="http://schemas.openxmlformats.org/drawingml/2006/picture">\n'
#  '                  <pic:nvPicPr>\n'
#  '                    <pic:cNvPr id="1" name="Picture 1">\n'
#  '                      <a:hlinkClick r:id="rId5"/>\n'
#  '                    </pic:cNvPr>\n'
#  '                    <pic:cNvPicPr>\n'
#  '                      <a:picLocks noChangeAspect="1" '
#  'noChangeArrowheads="1"/>\n'
#  '                    </pic:cNvPicPr>\n'
#  '                  </pic:nvPicPr>\n'
#  '                  <pic:blipFill>\n'
#  '                    <a:blip r:embed="rId6"/>\n'
#  '                    <a:stretch>\n'
#  '                      <a:fillRect/>\n'
#  '                    </a:stretch>\n'
#  '                  </pic:blipFill>\n'
#  '                  <pic:spPr bwMode="auto">\n'
#  '                    <a:xfrm>\n'
#  '                      <a:off x="0" y="0"/>\n'
#  '                      <a:ext cx="2133600" cy="457200"/>\n'
#  '                    </a:xfrm>\n'
#  '                    <a:prstGeom prst="rect">\n'
#  '                      <a:avLst/>\n'
#  '                    </a:prstGeom>\n'
#  '                  </pic:spPr>\n'
#  '                </pic:pic>\n'
#  '              </a:graphicData>\n'
#  '            </a:graphic>\n'
#  '          </wp:inline>\n'
#  '        </w:drawing>\n'
#  '      </w:r>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '        <w:br/>\n'
#  '        <w:t>Wedding Photography Contract</w:t>\n'
#  '      </w:r>\n'
#  '    </w:p>\n'
#  '    <w:p w14:paraId="0EF109E6" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="009E3D24">\n'
#  '      <w:pPr>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '    </w:p>\n'
#  '    <w:p w14:paraId="50158190" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="00D06DEA">\n'
#  '      <w:pPr>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '        <w:t>[AAA Photography Studios], located at [Address], agrees to '
#  'provide wedding photography services to the client(s) listed below.</w:t>\n'
#  '      </w:r>\n'
#  '    </w:p>\n'
#  '    <w:tbl>\n'
#  '      <w:tblPr>\n'
#  '        <w:tblStyle w:val="TableGrid"/>\n'
#  '        <w:tblW w:w="11017" w:type="dxa"/>\n'
#  '        <w:jc w:val="center"/>\n'
#  '        <w:tblLook w:val="04A0" w:firstRow="1" w:lastRow="0" '
#  'w:firstColumn="1" w:lastColumn="0" w:noHBand="0" w:noVBand="1"/>\n'
#  '      </w:tblPr>\n'
#  '      <w:tblGrid>\n'
#  '        <w:gridCol w:w="829"/>\n'
#  '        <w:gridCol w:w="900"/>\n'
#  '        <w:gridCol w:w="270"/>\n'
#  '        <w:gridCol w:w="1800"/>\n'
#  '        <w:gridCol w:w="989"/>\n'
#  '        <w:gridCol w:w="541"/>\n'
#  '        <w:gridCol w:w="990"/>\n'
#  '        <w:gridCol w:w="1260"/>\n'
#  '        <w:gridCol w:w="721"/>\n'
#  '        <w:gridCol w:w="2717"/>\n'
#  '      </w:tblGrid>\n'
#  '      <w:tr w:rsidR="009E3D24" w14:paraId="6077FB34" w14:textId="77777777">\n'
#  '        <w:trPr>\n'
#  '          <w:trHeight w:val="432"/>\n'
#  '          <w:jc w:val="center"/>\n'
#  '        </w:trPr>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="1728" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="2"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="64185650" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Client Name:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="9288" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="8"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="74F8F915" w14:textId="77777777" '
#  'w:rsidR="00D06DEA" w:rsidRDefault="00D06DEA" w:rsidP="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:pStyle w:val="Heading1"/>\n'
#  '              <w:outlineLvl w:val="0"/>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Wedding Photography Contract</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '          <w:p w14:paraId="0E788508" w14:textId="77777777" '
#  'w:rsidR="00D06DEA" w:rsidRDefault="00D06DEA" w:rsidP="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '          <w:p w14:paraId="409434AF" w14:textId="77777777" '
#  'w:rsidR="00D06DEA" w:rsidRDefault="00D06DEA" w:rsidP="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>[AAA Photography Studios], located at [Address], agrees '
#  'to provide wedding photography services to the client(s) listed '
#  'below.</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '          <w:p w14:paraId="14B43593" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:bookmarkStart w:id="0" w:name="_GoBack"/>\n'
#  '            <w:bookmarkEnd w:id="0"/>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '      </w:tr>\n'
#  '      <w:tr w:rsidR="009E3D24" w14:paraId="7E111D2B" w14:textId="77777777">\n'
#  '        <w:trPr>\n'
#  '          <w:trHeight w:val="432"/>\n'
#  '          <w:jc w:val="center"/>\n'
#  '        </w:trPr>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="1998" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="75ECD992" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Street address:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="9018" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="7"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="1A63B485" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '      </w:tr>\n'
#  '      <w:tr w:rsidR="009E3D24" w14:paraId="6D2A491E" w14:textId="77777777">\n'
#  '        <w:trPr>\n'
#  '          <w:trHeight w:val="432"/>\n'
#  '          <w:jc w:val="center"/>\n'
#  '        </w:trPr>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="828" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="7198E611" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>City:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="2970" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="11BF064D" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="989" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="68616FA4" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>State:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="2791" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="7D04E534" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="721" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="3FD9FB0B" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Zip:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="2717" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="2880B847" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '      </w:tr>\n'
#  '      <w:tr w:rsidR="009E3D24" w14:paraId="23289E8D" w14:textId="77777777">\n'
#  '        <w:trPr>\n'
#  '          <w:trHeight w:val="432"/>\n'
#  '          <w:jc w:val="center"/>\n'
#  '        </w:trPr>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="1998" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="0A43EF20" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Phone Number:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="3330" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="6B394F67" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="990" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="10A805C7" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Email:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="4698" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="18F25160" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '      </w:tr>\n'
#  '    </w:tbl>\n'
#  '    <w:p w14:paraId="6857566B" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="009E3D24">\n'
#  '      <w:pPr>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '    </w:p>\n'
#  '    <w:tbl>\n'
#  '      <w:tblPr>\n'
#  '        <w:tblStyle w:val="TableGrid"/>\n'
#  '        <w:tblW w:w="11017" w:type="dxa"/>\n'
#  '        <w:jc w:val="center"/>\n'
#  '        <w:tblLook w:val="04A0" w:firstRow="1" w:lastRow="0" '
#  'w:firstColumn="1" w:lastColumn="0" w:noHBand="0" w:noVBand="1"/>\n'
#  '      </w:tblPr>\n'
#  '      <w:tblGrid>\n'
#  '        <w:gridCol w:w="829"/>\n'
#  '        <w:gridCol w:w="900"/>\n'
#  '        <w:gridCol w:w="270"/>\n'
#  '        <w:gridCol w:w="1800"/>\n'
#  '        <w:gridCol w:w="989"/>\n'
#  '        <w:gridCol w:w="541"/>\n'
#  '        <w:gridCol w:w="990"/>\n'
#  '        <w:gridCol w:w="1260"/>\n'
#  '        <w:gridCol w:w="721"/>\n'
#  '        <w:gridCol w:w="2717"/>\n'
#  '      </w:tblGrid>\n'
#  '      <w:tr w:rsidR="009E3D24" w14:paraId="0F922433" w14:textId="77777777">\n'
#  '        <w:trPr>\n'
#  '          <w:trHeight w:val="432"/>\n'
#  '          <w:jc w:val="center"/>\n'
#  '        </w:trPr>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="1728" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="2"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="799B46D8" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t xml:space="preserve">Client </w:t>\n'
#  '            </w:r>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Name:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="9288" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="8"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="54F9D5F6" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '      </w:tr>\n'
#  '      <w:tr w:rsidR="009E3D24" w14:paraId="46523D27" w14:textId="77777777">\n'
#  '        <w:trPr>\n'
#  '          <w:trHeight w:val="432"/>\n'
#  '          <w:jc w:val="center"/>\n'
#  '        </w:trPr>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="1998" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="7483663B" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Street address:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="9018" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="7"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="6FF5DDFE" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '      </w:tr>\n'
#  '      <w:tr w:rsidR="009E3D24" w14:paraId="753D95A2" w14:textId="77777777">\n'
#  '        <w:trPr>\n'
#  '          <w:trHeight w:val="432"/>\n'
#  '          <w:jc w:val="center"/>\n'
#  '        </w:trPr>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="828" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="5C00DFF3" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>City:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="2970" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="289C64DD" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="989" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="12D6483B" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>State:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="2791" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="419DC006" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="721" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="5BDC6FAF" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Zip:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="2717" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="32B56DAF" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '      </w:tr>\n'
#  '      <w:tr w:rsidR="009E3D24" w14:paraId="5947980F" w14:textId="77777777">\n'
#  '        <w:trPr>\n'
#  '          <w:trHeight w:val="432"/>\n'
#  '          <w:jc w:val="center"/>\n'
#  '        </w:trPr>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="1998" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="56A2577E" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Phone Number:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="3330" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="2D036F7D" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="990" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="77D8EBC5" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Email:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="4698" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="57D9CAD8" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '      </w:tr>\n'
#  '    </w:tbl>\n'
#  '    <w:p w14:paraId="2AA15E41" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="00D06DEA">\n'
#  '      <w:pPr>\n'
#  '        <w:pStyle w:val="Heading2"/>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '        <w:t xml:space="preserve">Services: </w:t>\n'
#  '      </w:r>\n'
#  '    </w:p>\n'
#  '    <w:p w14:paraId="0BA99F2F" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="00D06DEA">\n'
#  '      <w:pPr>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '        <w:t>[AAA Photography Studios] will provide photography services at '
#  'two separate venues on [Date], beginning at [Start time]</w:t>\n'
#  '      </w:r>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '        <w:tab/>\n'
#  '        <w:t>am/pm and ending at [Ending time] am/pm.</w:t>\n'
#  '      </w:r>\n'
#  '    </w:p>\n'
#  '    <w:p w14:paraId="054C9110" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="00D06DEA">\n'
#  '      <w:pPr>\n'
#  '        <w:pStyle w:val="Heading2"/>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '        <w:t>Photography at Event Venue #1:</w:t>\n'
#  '      </w:r>\n'
#  '    </w:p>\n'
#  '    <w:tbl>\n'
#  '      <w:tblPr>\n'
#  '        <w:tblStyle w:val="TableGrid"/>\n'
#  '        <w:tblW w:w="11017" w:type="dxa"/>\n'
#  '        <w:jc w:val="center"/>\n'
#  '        <w:tblLook w:val="04A0" w:firstRow="1" w:lastRow="0" '
#  'w:firstColumn="1" w:lastColumn="0" w:noHBand="0" w:noVBand="1"/>\n'
#  '      </w:tblPr>\n'
#  '      <w:tblGrid>\n'
#  '        <w:gridCol w:w="829"/>\n'
#  '        <w:gridCol w:w="989"/>\n'
#  '        <w:gridCol w:w="181"/>\n'
#  '        <w:gridCol w:w="1800"/>\n'
#  '        <w:gridCol w:w="989"/>\n'
#  '        <w:gridCol w:w="721"/>\n'
#  '        <w:gridCol w:w="1981"/>\n'
#  '        <w:gridCol w:w="89"/>\n'
#  '        <w:gridCol w:w="721"/>\n'
#  '        <w:gridCol w:w="2717"/>\n'
#  '      </w:tblGrid>\n'
#  '      <w:tr w:rsidR="009E3D24" w14:paraId="43CDC554" w14:textId="77777777">\n'
#  '        <w:trPr>\n'
#  '          <w:trHeight w:val="432"/>\n'
#  '          <w:jc w:val="center"/>\n'
#  '        </w:trPr>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="1998" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="6565D51F" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Venue Name:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="9018" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="7"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="0EADFCF4" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '      </w:tr>\n'
#  '      <w:tr w:rsidR="009E3D24" w14:paraId="09969EFE" w14:textId="77777777">\n'
#  '        <w:trPr>\n'
#  '          <w:trHeight w:val="432"/>\n'
#  '          <w:jc w:val="center"/>\n'
#  '        </w:trPr>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="1998" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="3"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="4817F331" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Street Address:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="9018" w:type="dxa"/>\n'
#  '            <w:gridSpan w:val="7"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="59D98A2C" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '      </w:tr>\n'
#  '      <w:tr w:rsidR="009E3D24" w14:paraId="0CC9BF00" w14:textId="77777777">\n'
#  '        <w:trPr>\n'
#  '          <w:trHeight w:val="432"/>\n'
#  '          <w:jc w:val="center"/>\n'
#  '        </w:trPr>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="828" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="725E240D" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>City:</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
# ...
#  '            <w:tcW w:w="1908" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '            <w:vAlign w:val="bottom"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="237000E5" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '      </w:tr>\n'
#  '      <w:tr w:rsidR="009E3D24" w14:paraId="67BDDF73" w14:textId="77777777">\n'
#  '        <w:trPr>\n'
#  '          <w:trHeight w:val="576"/>\n'
#  '          <w:jc w:val="center"/>\n'
#  '        </w:trPr>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="4247" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="7C6EDB80" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Printed Name, Company</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="270" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="43E7B862" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="4321" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="2B995D3F" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Signature, Company Representative</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="270" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:top w:val="nil"/>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="359B04F7" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="009E3D24">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '        <w:tc>\n'
#  '          <w:tcPr>\n'
#  '            <w:tcW w:w="1908" w:type="dxa"/>\n'
#  '            <w:tcBorders>\n'
#  '              <w:left w:val="nil"/>\n'
#  '              <w:bottom w:val="nil"/>\n'
#  '              <w:right w:val="nil"/>\n'
#  '            </w:tcBorders>\n'
#  '            <w:shd w:val="clear" w:color="auto" w:fill="auto"/>\n'
#  '          </w:tcPr>\n'
#  '          <w:p w14:paraId="171A51B9" w14:textId="77777777" '
#  'w:rsidR="009E3D24" w:rsidRDefault="00D06DEA">\n'
#  '            <w:pPr>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '              </w:rPr>\n'
#  '            </w:pPr>\n'
#  '            <w:r>\n'
#  '              <w:rPr>\n'
#  '                <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '                <w:b/>\n'
#  '                <w:bCs/>\n'
#  '              </w:rPr>\n'
#  '              <w:t>Date</w:t>\n'
#  '            </w:r>\n'
#  '          </w:p>\n'
#  '        </w:tc>\n'
#  '      </w:tr>\n'
#  '    </w:tbl>\n'
#  '    <w:p w14:paraId="7A323649" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="009E3D24">\n'
#  '      <w:pPr>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '    </w:p>\n'
#  '    <w:p w14:paraId="735983DB" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="009E3D24">\n'
#  '      <w:pPr>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '    </w:p>\n'
#  '    <w:p w14:paraId="4C2453C8" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="00D06DEA">\n'
#  '      <w:pPr>\n'
#  '        <w:spacing w:after="200" w:line="276" w:lineRule="auto"/>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '      <w:r>\n'
#  '        <w:br w:type="page"/>\n'
#  '      </w:r>\n'
#  '    </w:p>\n'
#  '    <w:p w14:paraId="28AEF6CD" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="00D06DEA">\n'
#  '      <w:pPr>\n'
#  '        <w:pStyle w:val="NormalWeb"/>\n'
#  '        <w:pBdr>\n'
#  '          <w:top w:val="single" w:sz="24" w:space="10" w:color="9BBB59"/>\n'
#  '          <w:left w:val="single" w:sz="24" w:space="10" w:color="9BBB59"/>\n'
#  '          <w:right w:val="single" w:sz="24" w:space="10" w:color="9BBB59"/>\n'
#  '        </w:pBdr>\n'
#  '        <w:spacing w:beforeAutospacing="0" w:afterAutospacing="0"/>\n'
#  '        <w:jc w:val="both"/>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '          <w:color w:val="000000"/>\n'
#  '          <w:sz w:val="22"/>\n'
#  '          <w:szCs w:val="22"/>\n'
#  '        </w:rPr>\n'
#  '        <w:lastRenderedPageBreak/>\n'
#  '        <w:t>Copyright information - Please read</w:t>\n'
#  '      </w:r>\n'
#  '    </w:p>\n'
#  '    <w:p w14:paraId="5B3ED377" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="00D06DEA">\n'
#  '      <w:pPr>\n'
#  '        <w:pStyle w:val="NormalWeb"/>\n'
#  '        <w:pBdr>\n'
#  '          <w:left w:val="single" w:sz="24" w:space="10" w:color="9BBB59"/>\n'
#  '          <w:right w:val="single" w:sz="24" w:space="10" w:color="9BBB59"/>\n'
#  '        </w:pBdr>\n'
#  '        <w:spacing w:beforeAutospacing="0" w:afterAutospacing="0"/>\n'
#  '        <w:jc w:val="both"/>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '        <w:t>\xa0</w:t>\n'
#  '      </w:r>\n'
#  '    </w:p>\n'
#  '    <w:p w14:paraId="14435087" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="00D06DEA">\n'
#  '      <w:pPr>\n'
#  '        <w:pStyle w:val="NormalWeb"/>\n'
#  '        <w:pBdr>\n'
#  '          <w:left w:val="single" w:sz="24" w:space="10" w:color="9BBB59"/>\n'
#  '          <w:right w:val="single" w:sz="24" w:space="10" w:color="9BBB59"/>\n'
#  '        </w:pBdr>\n'
#  '        <w:spacing w:beforeAutospacing="0" w:afterAutospacing="0"/>\n'
#  '        <w:jc w:val="both"/>\n'
#  '      </w:pPr>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '          <w:color w:val="000000"/>\n'
#  '          <w:sz w:val="22"/>\n'
#  '          <w:szCs w:val="22"/>\n'
#  '        </w:rPr>\n'
#  '        <w:t xml:space="preserve">© This </w:t>\n'
#  '      </w:r>\n'
#  '      <w:hyperlink r:id="rId7">\n'
#  '        <w:r>\n'
#  '          <w:rPr>\n'
#  '            <w:rStyle w:val="InternetLink"/>\n'
#  '            <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '            <w:b/>\n'
#  '            <w:bCs/>\n'
#  '            <w:sz w:val="22"/>\n'
#  '            <w:szCs w:val="22"/>\n'
#  '          </w:rPr>\n'
#  '          <w:t>Free Microsoft Office Template</w:t>\n'
#  '        </w:r>\n'
#  '      </w:hyperlink>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '          <w:color w:val="000000"/>\n'
#  '          <w:sz w:val="22"/>\n'
#  '          <w:szCs w:val="22"/>\n'
#  '        </w:rPr>\n'
#  '        <w:t xml:space="preserve"> is the copyright of Hloom.com. You can '
#  'download and modify this template for your own personal use. You can (and '
#  'should!) remove this copyright notice (</w:t>\n'
#  '      </w:r>\n'
#  '      <w:hyperlink r:id="rId8">\n'
#  '        <w:r>\n'
#  '          <w:rPr>\n'
#  '            <w:rStyle w:val="InternetLink"/>\n'
#  '            <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '            <w:b/>\n'
#  '            <w:bCs/>\n'
#  '            <w:sz w:val="22"/>\n'
#  '            <w:szCs w:val="22"/>\n'
#  '          </w:rPr>\n'
#  '          <w:t>click here to see how</w:t>\n'
#  '        </w:r>\n'
#  '      </w:hyperlink>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '          <w:color w:val="000000"/>\n'
#  '          <w:sz w:val="22"/>\n'
#  '          <w:szCs w:val="22"/>\n'
#  '        </w:rPr>\n'
#  '        <w:t>) before custo</w:t>\n'
#  '      </w:r>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '          <w:color w:val="000000"/>\n'
#  '          <w:sz w:val="22"/>\n'
#  '          <w:szCs w:val="22"/>\n'
#  '        </w:rPr>\n'
#  '        <w:t>mizing the template.</w:t>\n'
#  '      </w:r>\n'
#  '    </w:p>\n'
#  '    <w:p w14:paraId="75750BC7" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="00D06DEA">\n'
#  '      <w:pPr>\n'
#  '        <w:pStyle w:val="NormalWeb"/>\n'
#  '        <w:pBdr>\n'
#  '          <w:left w:val="single" w:sz="24" w:space="10" w:color="9BBB59"/>\n'
#  '          <w:right w:val="single" w:sz="24" w:space="10" w:color="9BBB59"/>\n'
#  '        </w:pBdr>\n'
#  '        <w:spacing w:beforeAutospacing="0" w:afterAutospacing="0"/>\n'
#  '        <w:jc w:val="both"/>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '        <w:t>\xa0</w:t>\n'
#  '      </w:r>\n'
#  '    </w:p>\n'
#  '    <w:p w14:paraId="2651CF19" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="00D06DEA">\n'
#  '      <w:pPr>\n'
#  '        <w:pStyle w:val="NormalWeb"/>\n'
#  '        <w:pBdr>\n'
#  '          <w:left w:val="single" w:sz="24" w:space="10" w:color="9BBB59"/>\n'
#  '          <w:bottom w:val="single" w:sz="24" w:space="10" '
#  'w:color="9BBB59"/>\n'
#  '          <w:right w:val="single" w:sz="24" w:space="10" w:color="9BBB59"/>\n'
#  '        </w:pBdr>\n'
#  '        <w:spacing w:beforeAutospacing="0" w:afterAutospacing="0"/>\n'
#  '        <w:jc w:val="both"/>\n'
#  '      </w:pPr>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '          <w:color w:val="000000"/>\n'
#  '          <w:sz w:val="22"/>\n'
#  '          <w:szCs w:val="22"/>\n'
#  '        </w:rPr>\n'
#  '        <w:t xml:space="preserve">You may not distribute or resell this '
#  'template, or its derivatives, and you may not make it available on other '
#  'websites without our prior permission. All sharing of this template must be '
#  'done using a link to </w:t>\n'
#  '      </w:r>\n'
#  '      <w:hyperlink r:id="rId9">\n'
#  '        <w:r>\n'
#  '          <w:rPr>\n'
#  '            <w:rStyle w:val="InternetLink"/>\n'
#  '            <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '            <w:b/>\n'
#  '            <w:bCs/>\n'
#  '            <w:color w:val="1155CC"/>\n'
#  '            <w:sz w:val="22"/>\n'
#  '            <w:szCs w:val="22"/>\n'
#  '          </w:rPr>\n'
#  '          <w:t>http://www.hloom.com/</w:t>\n'
#  '        </w:r>\n'
#  '      </w:hyperlink>\n'
#  '      <w:r>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '          <w:color w:val="000000"/>\n'
#  '          <w:sz w:val="22"/>\n'
#  '          <w:szCs w:val="22"/>\n'
#  '        </w:rPr>\n'
#  '        <w:t xml:space="preserve">. For any questions relating to the use of '
#  'this template please email us - </w:t>\n'
#  '      </w:r>\n'
#  '      <w:hyperlink r:id="rId10">\n'
#  '        <w:r>\n'
#  '          <w:rPr>\n'
#  '            <w:rStyle w:val="InternetLink"/>\n'
#  '            <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '            <w:b/>\n'
#  '            <w:bCs/>\n'
#  '            <w:sz w:val="22"/>\n'
#  '            <w:szCs w:val="22"/>\n'
#  '          </w:rPr>\n'
#  '          <w:t>info@hloom.com</w:t>\n'
#  '        </w:r>\n'
#  '      </w:hyperlink>\n'
#  '    </w:p>\n'
#  '    <w:p w14:paraId="2B82CB06" w14:textId="77777777" w:rsidR="009E3D24" '
#  'w:rsidRDefault="009E3D24">\n'
#  '      <w:pPr>\n'
#  '        <w:rPr>\n'
#  '          <w:rFonts w:ascii="Arial Black" w:hAnsi="Arial Black"/>\n'
#  '          <w:b/>\n'
#  '          <w:bCs/>\n'
#  '        </w:rPr>\n'
#  '      </w:pPr>\n'
#  '    </w:p>\n'
#  '    <w:sectPr w:rsidR="009E3D24">\n'
#  '      <w:pgSz w:w="12240" w:h="15840"/>\n'
#  '      <w:pgMar w:top="720" w:right="720" w:bottom="720" w:left="720" '
#  'w:header="0" w:footer="0" w:gutter="0"/>\n'
#  '      <w:cols w:space="720"/>\n'
#  '      <w:formProt w:val="0"/>\n'
#  '      <w:docGrid w:linePitch="360" w:charSpace="4096"/>\n'
#  '    </w:sectPr>\n'
#  '  </w:body>\n'
#  '</w:document>\n')

# %%
from bs4 import BeautifulSoup




item = document.element.xml


soup = BeautifulSoup(item)

print(soup)

# foundItem = soup.find('sectPr')

# print(foundItem)
# Out:
# <html><body><w:document mc:ignorable="w14 w15 w16se w16cid wp14" xmlns:aink="http://schemas.microsoft.com/office/drawing/2016/ink" xmlns:am3d="http://schemas.microsoft.com/office/drawing/2017/model3d" xmlns:cx="http://schemas.microsoft.com/office/drawing/2014/chartex" xmlns:cx1="http://schemas.microsoft.com/office/drawing/2015/9/8/chartex" xmlns:cx2="http://schemas.microsoft.com/office/drawing/2015/10/21/chartex" xmlns:cx3="http://schemas.microsoft.com/office/drawing/2016/5/9/chartex" xmlns:cx4="http://schemas.microsoft.com/office/drawing/2016/5/10/chartex" xmlns:cx5="http://schemas.microsoft.com/office/drawing/2016/5/11/chartex" xmlns:cx6="http://schemas.microsoft.com/office/drawing/2016/5/12/chartex" xmlns:cx7="http://schemas.microsoft.com/office/drawing/2016/5/13/chartex" xmlns:cx8="http://schemas.microsoft.com/office/drawing/2016/5/14/chartex" xmlns:m="http://schemas.openxmlformats.org/officeDocument/2006/math" xmlns:mc="http://schemas.openxmlformats.org/markup-compatibility/2006" xmlns:o="urn:schemas-microsoft-com:office:office" xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" xmlns:w10="urn:schemas-microsoft-com:office:word" xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml" xmlns:w15="http://schemas.microsoft.com/office/word/2012/wordml" xmlns:w16cid="http://schemas.microsoft.com/office/word/2016/wordml/cid" xmlns:w16se="http://schemas.microsoft.com/office/word/2015/wordml/symex" xmlns:wne="http://schemas.microsoft.com/office/word/2006/wordml" xmlns:wp="http://schemas.openxmlformats.org/drawingml/2006/wordprocessingDrawing" xmlns:wp14="http://schemas.microsoft.com/office/word/2010/wordprocessingDrawing" xmlns:wpc="http://schemas.microsoft.com/office/word/2010/wordprocessingCanvas" xmlns:wpg="http://schemas.microsoft.com/office/word/2010/wordprocessingGroup" xmlns:wpi="http://schemas.microsoft.com/office/word/2010/wordprocessingInk" xmlns:wps="http://schemas.microsoft.com/office/word/2010/wordprocessingShape">
# <w:body>
# <w:p w14:paraid="4A5DE398" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:pstyle w:val="Heading1"></w:pstyle>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:bcs></w:bcs>
# <w:noproof></w:noproof>
# </w:rpr>
# <w:drawing>
# <wp:inline distb="0" distl="0" distr="0" distt="0" wp14:anchorid="53B36FF5" wp14:editid="25DAEE7C">
# <wp:extent cx="2133600" cy="457200"></wp:extent>
# <wp:effectextent b="0" l="0" r="0" t="0"></wp:effectextent>
# <wp:docpr id="1" name="Picture 1">
# <a:hlinkclick r:id="rId5" xmlns:a="http://schemas.openxmlformats.org/drawingml/2006/main"></a:hlinkclick>
# </wp:docpr>
# <wp:cnvgraphicframepr>
# <a:graphicframelocks nochangeaspect="1" xmlns:a="http://schemas.openxmlformats.org/drawingml/2006/main"></a:graphicframelocks>
# </wp:cnvgraphicframepr>
# <a:graphic xmlns:a="http://schemas.openxmlformats.org/drawingml/2006/main">
# <a:graphicdata uri="http://schemas.openxmlformats.org/drawingml/2006/picture">
# <pic:pic xmlns:pic="http://schemas.openxmlformats.org/drawingml/2006/picture">
# <pic:nvpicpr>
# <pic:cnvpr id="1" name="Picture 1">
# <a:hlinkclick r:id="rId5"></a:hlinkclick>
# </pic:cnvpr>
# <pic:cnvpicpr>
# <a:piclocks nochangearrowheads="1" nochangeaspect="1"></a:piclocks>
# </pic:cnvpicpr>
# </pic:nvpicpr>
# <pic:blipfill>
# <a:blip r:embed="rId6"></a:blip>
# <a:stretch>
# <a:fillrect></a:fillrect>
# </a:stretch>
# </pic:blipfill>
# <pic:sppr bwmode="auto">
# <a:xfrm>
# <a:off x="0" y="0"></a:off>
# <a:ext cx="2133600" cy="457200"></a:ext>
# </a:xfrm>
# <a:prstgeom prst="rect">
# <a:avlst></a:avlst>
# </a:prstgeom>
# </pic:sppr>
# </pic:pic>
# </a:graphicdata>
# </a:graphic>
# </wp:inline>
# </w:drawing>
# </w:r>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:br></w:br>
# <w:t>Wedding Photography Contract</w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="0EF109E6" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# <w:p w14:paraid="50158190" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>[AAA Photography Studios], located at [Address], agrees to provide wedding photography services to the client(s) listed below.</w:t>
# </w:r>
# </w:p>
# <w:tbl>
# <w:tblpr>
# <w:tblstyle w:val="TableGrid"></w:tblstyle>
# <w:tblw w:type="dxa" w:w="11017"></w:tblw>
# <w:jc w:val="center"></w:jc>
# <w:tbllook w:firstcolumn="1" w:firstrow="1" w:lastcolumn="0" w:lastrow="0" w:nohband="0" w:novband="1" w:val="04A0"></w:tbllook>
# </w:tblpr>
# <w:tblgrid>
# <w:gridcol w:w="829"></w:gridcol>
# <w:gridcol w:w="900"></w:gridcol>
# <w:gridcol w:w="270"></w:gridcol>
# <w:gridcol w:w="1800"></w:gridcol>
# <w:gridcol w:w="989"></w:gridcol>
# <w:gridcol w:w="541"></w:gridcol>
# <w:gridcol w:w="990"></w:gridcol>
# <w:gridcol w:w="1260"></w:gridcol>
# <w:gridcol w:w="721"></w:gridcol>
# <w:gridcol w:w="2717"></w:gridcol>
# </w:tblgrid>
# <w:tr w14:paraid="6077FB34" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="1728"></w:tcw>
# <w:gridspan w:val="2"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="64185650" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Client Name:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="9288"></w:tcw>
# <w:gridspan w:val="8"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="74F8F915" w14:textid="77777777" w:rsidp="00D06DEA" w:rsidr="00D06DEA" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:pstyle w:val="Heading1"></w:pstyle>
# <w:outlinelvl w:val="0"></w:outlinelvl>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Wedding Photography Contract</w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="0E788508" w14:textid="77777777" w:rsidp="00D06DEA" w:rsidr="00D06DEA" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# <w:p w14:paraid="409434AF" w14:textid="77777777" w:rsidp="00D06DEA" w:rsidr="00D06DEA" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>[AAA Photography Studios], located at [Address], agrees to provide wedding photography services to the client(s) listed below.</w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="14B43593" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# <w:bookmarkstart w:id="0" w:name="_GoBack"></w:bookmarkstart>
# <w:bookmarkend w:id="0"></w:bookmarkend>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="7E111D2B" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="1998"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="75ECD992" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Street address:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="9018"></w:tcw>
# <w:gridspan w:val="7"></w:gridspan>
# <w:tcborders>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="1A63B485" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="6D2A491E" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="828"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="7198E611" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>City:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2970"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="11BF064D" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="989"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="68616FA4" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>State:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2791"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="7D04E534" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="721"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="3FD9FB0B" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Zip:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2717"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="2880B847" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="23289E8D" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="1998"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="0A43EF20" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Phone Number:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="3330"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="6B394F67" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="990"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="10A805C7" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Email:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4698"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="18F25160" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# </w:tbl>
# <w:p w14:paraid="6857566B" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# <w:tbl>
# <w:tblpr>
# <w:tblstyle w:val="TableGrid"></w:tblstyle>
# <w:tblw w:type="dxa" w:w="11017"></w:tblw>
# <w:jc w:val="center"></w:jc>
# <w:tbllook w:firstcolumn="1" w:firstrow="1" w:lastcolumn="0" w:lastrow="0" w:nohband="0" w:novband="1" w:val="04A0"></w:tbllook>
# </w:tblpr>
# <w:tblgrid>
# <w:gridcol w:w="829"></w:gridcol>
# <w:gridcol w:w="900"></w:gridcol>
# <w:gridcol w:w="270"></w:gridcol>
# <w:gridcol w:w="1800"></w:gridcol>
# <w:gridcol w:w="989"></w:gridcol>
# <w:gridcol w:w="541"></w:gridcol>
# <w:gridcol w:w="990"></w:gridcol>
# <w:gridcol w:w="1260"></w:gridcol>
# <w:gridcol w:w="721"></w:gridcol>
# <w:gridcol w:w="2717"></w:gridcol>
# </w:tblgrid>
# <w:tr w14:paraid="0F922433" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="1728"></w:tcw>
# <w:gridspan w:val="2"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="799B46D8" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t xml:space="preserve">Client </w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Name:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="9288"></w:tcw>
# <w:gridspan w:val="8"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="54F9D5F6" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="46523D27" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="1998"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="7483663B" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Street address:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="9018"></w:tcw>
# <w:gridspan w:val="7"></w:gridspan>
# <w:tcborders>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="6FF5DDFE" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="753D95A2" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="828"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="5C00DFF3" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>City:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2970"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="289C64DD" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="989"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="12D6483B" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>State:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2791"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="419DC006" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="721"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="5BDC6FAF" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Zip:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2717"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="32B56DAF" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="5947980F" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="1998"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="56A2577E" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Phone Number:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="3330"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="2D036F7D" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="990"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="77D8EBC5" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Email:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4698"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="57D9CAD8" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# </w:tbl>
# <w:p w14:paraid="2AA15E41" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:pstyle w:val="Heading2"></w:pstyle>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t xml:space="preserve">Services: </w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="0BA99F2F" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>[AAA Photography Studios] will provide photography services at two separate venues on [Date], beginning at [Start time]</w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:tab></w:tab>
# <w:t>am/pm and ending at [Ending time] am/pm.</w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="054C9110" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:pstyle w:val="Heading2"></w:pstyle>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Photography at Event Venue #1:</w:t>
# </w:r>
# </w:p>
# <w:tbl>
# <w:tblpr>
# <w:tblstyle w:val="TableGrid"></w:tblstyle>
# <w:tblw w:type="dxa" w:w="11017"></w:tblw>
# <w:jc w:val="center"></w:jc>
# <w:tbllook w:firstcolumn="1" w:firstrow="1" w:lastcolumn="0" w:lastrow="0" w:nohband="0" w:novband="1" w:val="04A0"></w:tbllook>
# </w:tblpr>
# <w:tblgrid>
# <w:gridcol w:w="829"></w:gridcol>
# <w:gridcol w:w="989"></w:gridcol>
# <w:gridcol w:w="181"></w:gridcol>
# <w:gridcol w:w="1800"></w:gridcol>
# <w:gridcol w:w="989"></w:gridcol>
# <w:gridcol w:w="721"></w:gridcol>
# <w:gridcol w:w="1981"></w:gridcol>
# <w:gridcol w:w="89"></w:gridcol>
# <w:gridcol w:w="721"></w:gridcol>
# <w:gridcol w:w="2717"></w:gridcol>
# </w:tblgrid>
# <w:tr w14:paraid="43CDC554" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="1998"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="6565D51F" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Venue Name:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="9018"></w:tcw>
# <w:gridspan w:val="7"></w:gridspan>
# <w:tcborders>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="0EADFCF4" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="09969EFE" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="1998"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="4817F331" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Street Address:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="9018"></w:tcw>
# <w:gridspan w:val="7"></w:gridspan>
# <w:tcborders>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="59D98A2C" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="0CC9BF00" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="828"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="725E240D" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>City:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2970"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="209A0641" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="989"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="4FEEA515" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>State:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2791"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="113FFCAF" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="721"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="5ECD882F" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Zip:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2717"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="0DEE5F46" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="5F0490F0" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="1817"></w:tcw>
# <w:gridspan w:val="2"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="32B109D0" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Venue Phone:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="3691"></w:tcw>
# <w:gridspan w:val="4"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="4CD24DD9" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="1981"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="3B015D24" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Venue Contact:</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="3527"></w:tcw>
# <w:gridspan w:val="3"></w:gridspan>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="3E5F09B7" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# </w:tbl>
# <w:p w14:paraid="4D3930C3" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# <w:p w14:paraid="2610800F" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>The client(s) request the following poses at Venue #1:</w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="620D8368" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# <w:tbl>
# <w:tblpr>
# <w:tblstyle w:val="TableGrid"></w:tblstyle>
# <w:tblw w:type="dxa" w:w="11016"></w:tblw>
# <w:jc w:val="center"></w:jc>
# <w:tbllook w:firstcolumn="1" w:firstrow="1" w:lastcolumn="0" w:lastrow="0" w:nohband="0" w:novband="1" w:val="04A0"></w:tbllook>
# </w:tblpr>
# <w:tblgrid>
# <w:gridcol w:w="648"></w:gridcol>
# <w:gridcol w:w="4861"></w:gridcol>
# <w:gridcol w:w="630"></w:gridcol>
# <w:gridcol w:w="4877"></w:gridcol>
# </w:tblgrid>
# <w:tr w14:paraid="062CE5E9" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="647"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="3B772352" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:jc w:val="right"></w:jc>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>1.</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4861"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="6492C1E6" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Ex: Bride and Groom with Groom’s family</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="630"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="6D258ED6" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:jc w:val="right"></w:jc>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>7.</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4877"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="54E5925D" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="787D254C" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="647"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="037CD33F" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:jc w:val="right"></w:jc>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>2.</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4861"></w:tcw>
# <w:tcborders>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="66C0C2D2" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="630"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="0BFECF34" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:jc w:val="right"></w:jc>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>8.</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4877"></w:tcw>
# <w:tcborders>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="495FBA5C" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="476A870E" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="647"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="740CD88E" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:jc w:val="right"></w:jc>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:lastrenderedpagebreak></w:lastrenderedpagebreak>
# <w:t>3.</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4861"></w:tcw>
# <w:tcborders>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="2BDCBAD8" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="630"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="4DF8C2AA" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:jc w:val="right"></w:jc>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>9.</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4877"></w:tcw>
# <w:tcborders>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="5B50D790" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="6C0840CD" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="432"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="647"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="5CCBF276" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:jc w:val="right"></w:jc>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>4.</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4861"></w:tcw>
# ...
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Printed Name, Client</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="270"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# </w:tcpr>
# <w:p w14:paraid="54FBA5DA" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4321"></w:tcw>
# <w:tcborders>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# </w:tcpr>
# <w:p w14:paraid="551675BC" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Signature, Client</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="270"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# </w:tcpr>
# <w:p w14:paraid="59AF8975" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="1908"></w:tcw>
# <w:tcborders>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# </w:tcpr>
# <w:p w14:paraid="3E393761" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Date</w:t>
# </w:r>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="1ADF1D2C" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="576"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4247"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="2444ED92" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="270"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="035ACBB7" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4321"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="4D45DE82" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="270"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="0C75EF75" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="1908"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# <w:valign w:val="bottom"></w:valign>
# </w:tcpr>
# <w:p w14:paraid="237000E5" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="67BDDF73" w14:textid="77777777" w:rsidr="009E3D24">
# <w:trpr>
# <w:trheight w:val="576"></w:trheight>
# <w:jc w:val="center"></w:jc>
# </w:trpr>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4247"></w:tcw>
# <w:tcborders>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# </w:tcpr>
# <w:p w14:paraid="7C6EDB80" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Printed Name, Company</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="270"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# </w:tcpr>
# <w:p w14:paraid="43E7B862" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4321"></w:tcw>
# <w:tcborders>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# </w:tcpr>
# <w:p w14:paraid="2B995D3F" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Signature, Company Representative</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="270"></w:tcw>
# <w:tcborders>
# <w:top w:val="nil"></w:top>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# </w:tcpr>
# <w:p w14:paraid="359B04F7" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="1908"></w:tcw>
# <w:tcborders>
# <w:left w:val="nil"></w:left>
# <w:bottom w:val="nil"></w:bottom>
# <w:right w:val="nil"></w:right>
# </w:tcborders>
# <w:shd w:color="auto" w:fill="auto" w:val="clear"></w:shd>
# </w:tcpr>
# <w:p w14:paraid="171A51B9" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t>Date</w:t>
# </w:r>
# </w:p>
# </w:tc>
# </w:tr>
# </w:tbl>
# <w:p w14:paraid="7A323649" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# <w:p w14:paraid="735983DB" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# <w:p w14:paraid="4C2453C8" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:spacing w:after="200" w:line="276" w:linerule="auto"></w:spacing>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:br w:type="page"></w:br>
# </w:r>
# </w:p>
# <w:p w14:paraid="28AEF6CD" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:pstyle w:val="NormalWeb"></w:pstyle>
# <w:pbdr>
# <w:top w:color="9BBB59" w:space="10" w:sz="24" w:val="single"></w:top>
# <w:left w:color="9BBB59" w:space="10" w:sz="24" w:val="single"></w:left>
# <w:right w:color="9BBB59" w:space="10" w:sz="24" w:val="single"></w:right>
# </w:pbdr>
# <w:spacing w:afterautospacing="0" w:beforeautospacing="0"></w:spacing>
# <w:jc w:val="both"></w:jc>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# <w:color w:val="000000"></w:color>
# <w:sz w:val="22"></w:sz>
# <w:szcs w:val="22"></w:szcs>
# </w:rpr>
# <w:lastrenderedpagebreak></w:lastrenderedpagebreak>
# <w:t>Copyright information - Please read</w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="5B3ED377" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:pstyle w:val="NormalWeb"></w:pstyle>
# <w:pbdr>
# <w:left w:color="9BBB59" w:space="10" w:sz="24" w:val="single"></w:left>
# <w:right w:color="9BBB59" w:space="10" w:sz="24" w:val="single"></w:right>
# </w:pbdr>
# <w:spacing w:afterautospacing="0" w:beforeautospacing="0"></w:spacing>
# <w:jc w:val="both"></w:jc>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t> </w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="14435087" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:pstyle w:val="NormalWeb"></w:pstyle>
# <w:pbdr>
# <w:left w:color="9BBB59" w:space="10" w:sz="24" w:val="single"></w:left>
# <w:right w:color="9BBB59" w:space="10" w:sz="24" w:val="single"></w:right>
# </w:pbdr>
# <w:spacing w:afterautospacing="0" w:beforeautospacing="0"></w:spacing>
# <w:jc w:val="both"></w:jc>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# <w:color w:val="000000"></w:color>
# <w:sz w:val="22"></w:sz>
# <w:szcs w:val="22"></w:szcs>
# </w:rpr>
# <w:t xml:space="preserve">© This </w:t>
# </w:r>
# <w:hyperlink r:id="rId7">
# <w:r>
# <w:rpr>
# <w:rstyle w:val="InternetLink"></w:rstyle>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# <w:sz w:val="22"></w:sz>
# <w:szcs w:val="22"></w:szcs>
# </w:rpr>
# <w:t>Free Microsoft Office Template</w:t>
# </w:r>
# </w:hyperlink>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# <w:color w:val="000000"></w:color>
# <w:sz w:val="22"></w:sz>
# <w:szcs w:val="22"></w:szcs>
# </w:rpr>
# <w:t xml:space="preserve"> is the copyright of Hloom.com. You can download and modify this template for your own personal use. You can (and should!) remove this copyright notice (</w:t>
# </w:r>
# <w:hyperlink r:id="rId8">
# <w:r>
# <w:rpr>
# <w:rstyle w:val="InternetLink"></w:rstyle>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# <w:sz w:val="22"></w:sz>
# <w:szcs w:val="22"></w:szcs>
# </w:rpr>
# <w:t>click here to see how</w:t>
# </w:r>
# </w:hyperlink>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# <w:color w:val="000000"></w:color>
# <w:sz w:val="22"></w:sz>
# <w:szcs w:val="22"></w:szcs>
# </w:rpr>
# <w:t>) before custo</w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# <w:color w:val="000000"></w:color>
# <w:sz w:val="22"></w:sz>
# <w:szcs w:val="22"></w:szcs>
# </w:rpr>
# <w:t>mizing the template.</w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="75750BC7" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:pstyle w:val="NormalWeb"></w:pstyle>
# <w:pbdr>
# <w:left w:color="9BBB59" w:space="10" w:sz="24" w:val="single"></w:left>
# <w:right w:color="9BBB59" w:space="10" w:sz="24" w:val="single"></w:right>
# </w:pbdr>
# <w:spacing w:afterautospacing="0" w:beforeautospacing="0"></w:spacing>
# <w:jc w:val="both"></w:jc>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# <w:t> </w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="2651CF19" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="00D06DEA">
# <w:ppr>
# <w:pstyle w:val="NormalWeb"></w:pstyle>
# <w:pbdr>
# <w:left w:color="9BBB59" w:space="10" w:sz="24" w:val="single"></w:left>
# <w:bottom w:color="9BBB59" w:space="10" w:sz="24" w:val="single"></w:bottom>
# <w:right w:color="9BBB59" w:space="10" w:sz="24" w:val="single"></w:right>
# </w:pbdr>
# <w:spacing w:afterautospacing="0" w:beforeautospacing="0"></w:spacing>
# <w:jc w:val="both"></w:jc>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# <w:color w:val="000000"></w:color>
# <w:sz w:val="22"></w:sz>
# <w:szcs w:val="22"></w:szcs>
# </w:rpr>
# <w:t xml:space="preserve">You may not distribute or resell this template, or its derivatives, and you may not make it available on other websites without our prior permission. All sharing of this template must be done using a link to </w:t>
# </w:r>
# <w:hyperlink r:id="rId9">
# <w:r>
# <w:rpr>
# <w:rstyle w:val="InternetLink"></w:rstyle>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# <w:color w:val="1155CC"></w:color>
# <w:sz w:val="22"></w:sz>
# <w:szcs w:val="22"></w:szcs>
# </w:rpr>
# <w:t>http://www.hloom.com/</w:t>
# </w:r>
# </w:hyperlink>
# <w:r>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# <w:color w:val="000000"></w:color>
# <w:sz w:val="22"></w:sz>
# <w:szcs w:val="22"></w:szcs>
# </w:rpr>
# <w:t xml:space="preserve">. For any questions relating to the use of this template please email us - </w:t>
# </w:r>
# <w:hyperlink r:id="rId10">
# <w:r>
# <w:rpr>
# <w:rstyle w:val="InternetLink"></w:rstyle>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# <w:sz w:val="22"></w:sz>
# <w:szcs w:val="22"></w:szcs>
# </w:rpr>
# <w:t>info@hloom.com</w:t>
# </w:r>
# </w:hyperlink>
# </w:p>
# <w:p w14:paraid="2B82CB06" w14:textid="77777777" w:rsidr="009E3D24" w:rsidrdefault="009E3D24">
# <w:ppr>
# <w:rpr>
# <w:rfonts w:ascii="Arial Black" w:hansi="Arial Black"></w:rfonts>
# <w:b></w:b>
# <w:bcs></w:bcs>
# </w:rpr>
# </w:ppr>
# </w:p>
# <w:sectpr w:rsidr="009E3D24">
# <w:pgsz w:h="15840" w:w="12240"></w:pgsz>
# <w:pgmar w:bottom="720" w:footer="0" w:gutter="0" w:header="0" w:left="720" w:right="720" w:top="720"></w:pgmar>
# <w:cols w:space="720"></w:cols>
# <w:formprot w:val="0"></w:formprot>
# <w:docgrid w:charspace="4096" w:linepitch="360"></w:docgrid>
# </w:sectpr>
# </w:body>
# </w:document>
# </body></html>

# %%
#step one or the main area where the page data is located

responseFind = soup.find('w:sectpr')

print(responseFind)
# Out:
# <w:sectpr w:rsidr="009E3D24">
# <w:pgsz w:h="15840" w:w="12240"></w:pgsz>
# <w:pgmar w:bottom="720" w:footer="0" w:gutter="0" w:header="0" w:left="720" w:right="720" w:top="720"></w:pgmar>
# <w:cols w:space="720"></w:cols>
# <w:formprot w:val="0"></w:formprot>
# <w:docgrid w:charspace="4096" w:linepitch="360"></w:docgrid>
# </w:sectpr>

# %%
#step two (the second paragraph)
responseFind2 = responseFind.find('w:pgmar')

print(responseFind2)
# Out:
# <w:pgmar w:bottom="720" w:footer="0" w:gutter="0" w:header="0" w:left="720" w:right="720" w:top="720"></w:pgmar>

# %%
#step three or the data to get

responseFind3 = responseFind2['w:left']

print(responseFind3)
# Out:
# 720

# %%
#All three steps at once

responseFindEnd = soup.find('w:sectpr').find('w:pgmar')['w:left']

print(responseFindEnd)
# Out:
# 720

# %%
##### this is all the steps to get the page general settings

from docx import Document

from bs4 import BeautifulSoup




# OriginalDocument = 'TestDocNoChangeAllBoldArialBlack2.docx'


OriginalDocument = 'DifferentLineText6.docx'

Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'




LocOriginalDocument = Location + OriginalDocument


wordDocument = LocOriginalDocument


document = Document(wordDocument)


item = document.element.xml


soup = BeautifulSoup(item)



responseFind = soup.find('w:sectpr')

stringData = str(responseFind)

print(stringData)



import pprint

pprint.pprint(item)

responseFind2 = soup.find('w:body').findChildren('w:p', recursive=False)



pprint.pprint(responseFind2)
# Out:
# [<w:p w14:paraid="06BB78D6" w14:textid="77777777" w:rsidr="00E04043" w:rsidrdefault="00882AAF">
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:t xml:space="preserve">This is part 1, </w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve">This is part 2, </w:t>
# </w:r>
# <w:r>
# <w:t xml:space="preserve">Part3, </w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Part 4.</w:t>
# </w:r>
# </w:p>,
#  <w:p w14:paraid="61174D08" w14:textid="77777777" w:rsidr="00853AE9" w:rsidrdefault="00853AE9">
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# </w:p>,
#  <w:p w14:paraid="55F31AF3" w14:textid="3F50315C" w:rsidr="00853AE9" w:rsidrdefault="00853AE9">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new Paragraph</w:t>
# </w:r>
# </w:p>,
#  <w:p w14:paraid="02825DD5" w14:textid="4A51CA08" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>,
#  <w:p w14:paraid="3EC06DEC" w14:textid="7745C87A" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>,
#  <w:p w14:paraid="4B28F70B" w14:textid="77777777" w:rsidr="00490B75" w:rsidrdefault="00490B75" w:rsidrpr="00CC2CDD">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>]

# %%
print(len(responseFind2))
# Out:
# 6

# %%
id = 0

ParagraphList= []
for i in responseFind2:
    print(i)
    print('=========================================')
    
    ItemList = []
    for x in i:
        print(id)
        id = id + 1
        print(x)
        
        if x == '\n':
            pass
        else:
            ItemList.append(x)
            
            
            print('|||||||||||||||||||||||||||||||||||||||||||||||||')
            
    ParagraphList.append(ItemList)
    
    
pprint.pprint(ParagraphList)
# Out:
# <w:p w14:paraid="06BB78D6" w14:textid="77777777" w:rsidr="00E04043" w:rsidrdefault="00882AAF">
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:t xml:space="preserve">This is part 1, </w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve">This is part 2, </w:t>
# </w:r>
# <w:r>
# <w:t xml:space="preserve">Part3, </w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Part 4.</w:t>
# </w:r>
# </w:p>
# =========================================
# 0
#
#
# 1
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# |||||||||||||||||||||||||||||||||||||||||||||||||
# 2
#
#
# 3
# <w:r>
# <w:t xml:space="preserve">This is part 1, </w:t>
# </w:r>
# |||||||||||||||||||||||||||||||||||||||||||||||||
# 4
#
#
# 5
# <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve">This is part 2, </w:t>
# </w:r>
# |||||||||||||||||||||||||||||||||||||||||||||||||
# 6
#
#
# 7
# <w:r>
# <w:t xml:space="preserve">Part3, </w:t>
# </w:r>
# |||||||||||||||||||||||||||||||||||||||||||||||||
# 8
#
#
# 9
# <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Part 4.</w:t>
# </w:r>
# |||||||||||||||||||||||||||||||||||||||||||||||||
# 10
#
#
# <w:p w14:paraid="61174D08" w14:textid="77777777" w:rsidr="00853AE9" w:rsidrdefault="00853AE9">
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# </w:p>
# =========================================
# 11
#
#
# 12
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# |||||||||||||||||||||||||||||||||||||||||||||||||
# 13
#
#
# <w:p w14:paraid="55F31AF3" w14:textid="3F50315C" w:rsidr="00853AE9" w:rsidrdefault="00853AE9">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new Paragraph</w:t>
# </w:r>
# </w:p>
# =========================================
# 14
#
#
# 15
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# |||||||||||||||||||||||||||||||||||||||||||||||||
# 16
#
#
# 17
# <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new Paragraph</w:t>
# </w:r>
# |||||||||||||||||||||||||||||||||||||||||||||||||
# 18
#
#
# <w:p w14:paraid="02825DD5" w14:textid="4A51CA08" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>
# =========================================
# 19
#
#
# 20
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# |||||||||||||||||||||||||||||||||||||||||||||||||
# 21
#
#
# <w:p w14:paraid="3EC06DEC" w14:textid="7745C87A" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>
# =========================================
# 22
#
#
# 23
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# |||||||||||||||||||||||||||||||||||||||||||||||||
# 24
#
#
# <w:p w14:paraid="4B28F70B" w14:textid="77777777" w:rsidr="00490B75" w:rsidrdefault="00490B75" w:rsidrpr="00CC2CDD">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>
# =========================================
# 25
#
#
# 26
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# |||||||||||||||||||||||||||||||||||||||||||||||||
# 27
#
#
# [[<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>,
#   <w:r>
# <w:t xml:space="preserve">This is part 1, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve">This is part 2, </w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve">Part3, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Part 4.</w:t>
# </w:r>],
#  [<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>,
#   <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new Paragraph</w:t>
# </w:r>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>]]

# %%
pprint.pprint(ParagraphList[0])
# Out:
# [<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>,
#  <w:r>
# <w:t xml:space="preserve">This is part 1, </w:t>
# </w:r>,
#  <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve">This is part 2, </w:t>
# </w:r>,
#  <w:r>
# <w:t xml:space="preserve">Part3, </w:t>
# </w:r>,
#  <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Part 4.</w:t>
# </w:r>]

# %%
pprint.pprint(ParagraphList[0][0])
# Out:
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>

# %%
pprint.pprint(responseFind2.find())

# %%
# id = 0

PprParagraphList= []
for i in responseFind2:
    print(i)
    print('=========================================')
    
    ppr = i.find_all('w:ppr')
    
    PprParagraphList.append(ppr)
    
    
pprint.pprint(PprParagraphList)
# Out:
# <w:p w14:paraid="06BB78D6" w14:textid="77777777" w:rsidr="00E04043" w:rsidrdefault="00882AAF">
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:t xml:space="preserve">This is part 1, </w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve">This is part 2, </w:t>
# </w:r>
# <w:r>
# <w:t xml:space="preserve">Part3, </w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Part 4.</w:t>
# </w:r>
# </w:p>
# =========================================
# <w:p w14:paraid="61174D08" w14:textid="77777777" w:rsidr="00853AE9" w:rsidrdefault="00853AE9">
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# </w:p>
# =========================================
# <w:p w14:paraid="55F31AF3" w14:textid="3F50315C" w:rsidr="00853AE9" w:rsidrdefault="00853AE9">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new Paragraph</w:t>
# </w:r>
# </w:p>
# =========================================
# <w:p w14:paraid="02825DD5" w14:textid="4A51CA08" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>
# =========================================
# <w:p w14:paraid="3EC06DEC" w14:textid="7745C87A" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>
# =========================================
# <w:p w14:paraid="4B28F70B" w14:textid="77777777" w:rsidr="00490B75" w:rsidrdefault="00490B75" w:rsidrpr="00CC2CDD">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>
# =========================================
# [[<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>]]

# %%
# id = 0

WrParagraphList= []
for i in responseFind2:
    print(i)
    print('=========================================')
    
    Wr = i.find_all('w:r')
    
    if Wr == []:
        pass
    
    else:   
        WrParagraphList.append(Wr)
    
    
pprint.pprint(WrParagraphList)
# Out:
# <w:p w14:paraid="06BB78D6" w14:textid="77777777" w:rsidr="00E04043" w:rsidrdefault="00882AAF">
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:t xml:space="preserve">This is part 1, </w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve">This is part 2, </w:t>
# </w:r>
# <w:r>
# <w:t xml:space="preserve">Part3, </w:t>
# </w:r>
# <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Part 4.</w:t>
# </w:r>
# </w:p>
# =========================================
# <w:p w14:paraid="61174D08" w14:textid="77777777" w:rsidr="00853AE9" w:rsidrdefault="00853AE9">
# <w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>
# </w:p>
# =========================================
# <w:p w14:paraid="55F31AF3" w14:textid="3F50315C" w:rsidr="00853AE9" w:rsidrdefault="00853AE9">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new Paragraph</w:t>
# </w:r>
# </w:p>
# =========================================
# <w:p w14:paraid="02825DD5" w14:textid="4A51CA08" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>
# =========================================
# <w:p w14:paraid="3EC06DEC" w14:textid="7745C87A" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>
# =========================================
# <w:p w14:paraid="4B28F70B" w14:textid="77777777" w:rsidr="00490B75" w:rsidrdefault="00490B75" w:rsidrpr="00CC2CDD">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# </w:p>
# =========================================
# [[<w:r>
# <w:t xml:space="preserve">This is part 1, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve">This is part 2, </w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve">Part3, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Part 4.</w:t>
# </w:r>],
#  [<w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new Paragraph</w:t>
# </w:r>]]

# %%
from docx import Document

from bs4 import BeautifulSoup

import pprint

##### this shows page size settings and header and footer settinggs




OriginalDocument = 'LandscapeTest.docx'

Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'




LocOriginalDocument = Location + OriginalDocument


wordDocument = LocOriginalDocument


document = Document(wordDocument)


item = document.element.xml


soup = BeautifulSoup(item)


pprint.pprint(soup)
# responseFind = soup.find('w:sectpr')

# stringData = str(responseFind)

# print(stringData)
# Out:
# <html><body><w:document mc:ignorable="w14 w15 w16se w16cid wp14" xmlns:aink="http://schemas.microsoft.com/office/drawing/2016/ink" xmlns:am3d="http://schemas.microsoft.com/office/drawing/2017/model3d" xmlns:cx="http://schemas.microsoft.com/office/drawing/2014/chartex" xmlns:cx1="http://schemas.microsoft.com/office/drawing/2015/9/8/chartex" xmlns:cx2="http://schemas.microsoft.com/office/drawing/2015/10/21/chartex" xmlns:cx3="http://schemas.microsoft.com/office/drawing/2016/5/9/chartex" xmlns:cx4="http://schemas.microsoft.com/office/drawing/2016/5/10/chartex" xmlns:cx5="http://schemas.microsoft.com/office/drawing/2016/5/11/chartex" xmlns:cx6="http://schemas.microsoft.com/office/drawing/2016/5/12/chartex" xmlns:cx7="http://schemas.microsoft.com/office/drawing/2016/5/13/chartex" xmlns:cx8="http://schemas.microsoft.com/office/drawing/2016/5/14/chartex" xmlns:m="http://schemas.openxmlformats.org/officeDocument/2006/math" xmlns:mc="http://schemas.openxmlformats.org/markup-compatibility/2006" xmlns:o="urn:schemas-microsoft-com:office:office" xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" xmlns:w10="urn:schemas-microsoft-com:office:word" xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml" xmlns:w15="http://schemas.microsoft.com/office/word/2012/wordml" xmlns:w16cid="http://schemas.microsoft.com/office/word/2016/wordml/cid" xmlns:w16se="http://schemas.microsoft.com/office/word/2015/wordml/symex" xmlns:wne="http://schemas.microsoft.com/office/word/2006/wordml" xmlns:wp="http://schemas.openxmlformats.org/drawingml/2006/wordprocessingDrawing" xmlns:wp14="http://schemas.microsoft.com/office/word/2010/wordprocessingDrawing" xmlns:wpc="http://schemas.microsoft.com/office/word/2010/wordprocessingCanvas" xmlns:wpg="http://schemas.microsoft.com/office/word/2010/wordprocessingGroup" xmlns:wpi="http://schemas.microsoft.com/office/word/2010/wordprocessingInk" xmlns:wps="http://schemas.microsoft.com/office/word/2010/wordprocessingShape">
# <w:body>
# <w:p w14:paraid="5063CBE2" w14:textid="674CB62A" w:rsidp="001F76FF" w:rsidr="00B123FC" w:rsidrdefault="001F76FF">
# <w:ppr>
# <w:spacing w:after="720" w:before="720"></w:spacing>
# <w:ind w:left="1440" w:right="1440"></w:ind>
# </w:ppr>
# <w:r>
# <w:t>Landscape test</w:t>
# </w:r>
# <w:bookmarkstart w:id="0" w:name="_GoBack"></w:bookmarkstart>
# <w:bookmarkend w:id="0"></w:bookmarkend>
# </w:p>
# <w:sectpr w:rsidr="00B123FC" w:rsidsect="001F76FF">
# <w:pgsz w:h="12240" w:orient="landscape" w:w="15840"></w:pgsz>
# <w:pgmar w:bottom="1440" w:footer="720" w:gutter="0" w:header="720" w:left="1440" w:right="1440" w:top="1440"></w:pgmar>
# <w:cols w:space="720"></w:cols>
# <w:docgrid w:linepitch="360"></w:docgrid>
# </w:sectpr>
# </w:body>
# </w:document>
# </body></html>

# %%
from docx import Document

from bs4 import BeautifulSoup

import pprint

##### this shows page size settings and header and footer settinggs




OriginalDocument = 'PortraitTest.docx'

Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'




LocOriginalDocument = Location + OriginalDocument


wordDocument = LocOriginalDocument


document = Document(wordDocument)


item = document.element.xml


soup = BeautifulSoup(item)


pprint.pprint(soup)
# responseFind = soup.find('w:sectpr')

# stringData = str(responseFind)

# print(stringData)
# Out:
# <html><body><w:document mc:ignorable="w14 w15 w16se w16cid wp14" xmlns:aink="http://schemas.microsoft.com/office/drawing/2016/ink" xmlns:am3d="http://schemas.microsoft.com/office/drawing/2017/model3d" xmlns:cx="http://schemas.microsoft.com/office/drawing/2014/chartex" xmlns:cx1="http://schemas.microsoft.com/office/drawing/2015/9/8/chartex" xmlns:cx2="http://schemas.microsoft.com/office/drawing/2015/10/21/chartex" xmlns:cx3="http://schemas.microsoft.com/office/drawing/2016/5/9/chartex" xmlns:cx4="http://schemas.microsoft.com/office/drawing/2016/5/10/chartex" xmlns:cx5="http://schemas.microsoft.com/office/drawing/2016/5/11/chartex" xmlns:cx6="http://schemas.microsoft.com/office/drawing/2016/5/12/chartex" xmlns:cx7="http://schemas.microsoft.com/office/drawing/2016/5/13/chartex" xmlns:cx8="http://schemas.microsoft.com/office/drawing/2016/5/14/chartex" xmlns:m="http://schemas.openxmlformats.org/officeDocument/2006/math" xmlns:mc="http://schemas.openxmlformats.org/markup-compatibility/2006" xmlns:o="urn:schemas-microsoft-com:office:office" xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" xmlns:w10="urn:schemas-microsoft-com:office:word" xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml" xmlns:w15="http://schemas.microsoft.com/office/word/2012/wordml" xmlns:w16cid="http://schemas.microsoft.com/office/word/2016/wordml/cid" xmlns:w16se="http://schemas.microsoft.com/office/word/2015/wordml/symex" xmlns:wne="http://schemas.microsoft.com/office/word/2006/wordml" xmlns:wp="http://schemas.openxmlformats.org/drawingml/2006/wordprocessingDrawing" xmlns:wp14="http://schemas.microsoft.com/office/word/2010/wordprocessingDrawing" xmlns:wpc="http://schemas.microsoft.com/office/word/2010/wordprocessingCanvas" xmlns:wpg="http://schemas.microsoft.com/office/word/2010/wordprocessingGroup" xmlns:wpi="http://schemas.microsoft.com/office/word/2010/wordprocessingInk" xmlns:wps="http://schemas.microsoft.com/office/word/2010/wordprocessingShape">
# <w:body>
# <w:p w14:paraid="5063CBE2" w14:textid="6596EBFD" w:rsidp="00200011" w:rsidr="00B123FC" w:rsidrdefault="00200011">
# <w:ppr>
# <w:spacing w:after="0"></w:spacing>
# </w:ppr>
# <w:r>
# <w:t>PortraitT</w:t>
# </w:r>
# <w:r w:rsidr="001F76FF">
# <w:t>est</w:t>
# </w:r>
# <w:bookmarkstart w:id="0" w:name="_GoBack"></w:bookmarkstart>
# <w:bookmarkend w:id="0"></w:bookmarkend>
# </w:p>
# <w:sectpr w:rsidr="00B123FC" w:rsidsect="00200011">
# <w:pgsz w:h="15840" w:w="12240"></w:pgsz>
# <w:pgmar w:bottom="1440" w:footer="720" w:gutter="0" w:header="720" w:left="1440" w:right="1440" w:top="1440"></w:pgmar>
# <w:cols w:space="720"></w:cols>
# <w:docgrid w:linepitch="360"></w:docgrid>
# </w:sectpr>
# </w:body>
# </w:document>
# </body></html>

# %%
##### this is all the steps to get the page general settings

from docx import Document

from bs4 import BeautifulSoup

##### this shows page size settings and header and footer and landscape settings




OriginalDocument = 'LandscapeTest.docx'

Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'




LocOriginalDocument = Location + OriginalDocument


wordDocument = LocOriginalDocument


document = Document(wordDocument)


item = document.element.xml


soup = BeautifulSoup(item)



responseFind = soup.find('w:sectpr')

stringData = str(responseFind)

print(stringData)
# Out:
# <w:sectpr w:rsidr="00B123FC" w:rsidsect="001F76FF">
# <w:pgsz w:h="12240" w:orient="landscape" w:w="15840"></w:pgsz>
# <w:pgmar w:bottom="1440" w:footer="720" w:gutter="0" w:header="720" w:left="1440" w:right="1440" w:top="1440"></w:pgmar>
# <w:cols w:space="720"></w:cols>
# <w:docgrid w:linepitch="360"></w:docgrid>
# </w:sectpr>

# %%
# this is to get the original text data information

##### this is all the steps to get the page general settings

from docx import Document

from bs4 import BeautifulSoup

import pprint


# OriginalDocument = 'TestDocNoChangeAllBoldArialBlack2.docx'


OriginalDocument = 'DifferentLineText6.docx'

Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'




LocOriginalDocument = Location + OriginalDocument


wordDocument = LocOriginalDocument


document = Document(wordDocument)


item = document.element.xml


soup = BeautifulSoup(item)



responseFind = soup.find('w:sectpr')

stringData = str(responseFind)

# print(stringData)



# pprint.pprint(item)

responseFind2 = soup.find('w:body').findChildren('w:p', recursive=False)



# pprint.pprint(responseFind2)

PprParagraphList= []
WrParagraphList= []
for i in responseFind2:
#     print(i)
#     print('=========================================')
    
    
    
    ppr = i.find_all('w:ppr')
    
    PprParagraphList.append(ppr)
    
    Wr = i.find_all('w:r')
    
    if Wr == []:
        pass
    
    else:   
        WrParagraphList.append(Wr)
    
### This shows text and text configuration (ex. underline, bold, italic etc)    
pprint.pprint(WrParagraphList)

print('===================================')
print('===================================')
print('===================================')

### this shows spacing
pprint.pprint(PprParagraphList)
# Out:
# [[<w:r>
# <w:t xml:space="preserve">This is part 1, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t xml:space="preserve">This is part 2, </w:t>
# </w:r>,
#   <w:r>
# <w:t xml:space="preserve">Part3, </w:t>
# </w:r>,
#   <w:r>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# <w:t>Part 4.</w:t>
# </w:r>],
#  [<w:r w:rsidrpr="00CC2CDD">
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>This is the new Paragraph</w:t>
# </w:r>]]
# ===================================
# ===================================
# ===================================
# [[<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:i></w:i>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>],
#  [<w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>]]

# %%
###### TODO get the data from table bellow



from docx import Document

from bs4 import BeautifulSoup

import pprint


# OriginalDocument = 'TestDocNoChangeAllBoldArialBlack2.docx'


OriginalDocument = 'DifferentLineText6TableOnly.docx'

Location = r'C:\Users\IgorDC\Desktop\PydocTest' + '\\'




LocOriginalDocument = Location + OriginalDocument


wordDocument = LocOriginalDocument


document = Document(wordDocument)


item = document.element.xml


soup = BeautifulSoup(item)


# pprint.pprint(soup)

Table = soup.find('w:tbl')

print(Table)
# Out:
# <w:tbl>
# <w:tblpr>
# <w:tblstyle w:val="TableGrid"></w:tblstyle>
# <w:tblw w:type="auto" w:w="0"></w:tblw>
# <w:tbllook w:firstcolumn="1" w:firstrow="1" w:lastcolumn="0" w:lastrow="0" w:nohband="0" w:novband="1" w:val="04A0"></w:tbllook>
# </w:tblpr>
# <w:tblgrid>
# <w:gridcol w:w="2337"></w:gridcol>
# <w:gridcol w:w="2337"></w:gridcol>
# <w:gridcol w:w="2338"></w:gridcol>
# <w:gridcol w:w="2338"></w:gridcol>
# </w:tblgrid>
# <w:tr w14:paraid="260A5970" w14:textid="77777777" w:rsidr="00490B75" w:rsidtr="00490B75">
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="18F63C89" w14:textid="6A8ABFB7" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>A1</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="397D01ED" w14:textid="34A23770" w:rsidr="00490B75" w:rsidrdefault="00490B75" w:rsidrpr="00490B75">
# <w:r>
# <w:t>A2</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="0BBFB6BF" w14:textid="5971FE64" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>A3</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="54D2621A" w14:textid="5261E162" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>A4</w:t>
# </w:r>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="6633294A" w14:textid="77777777" w:rsidr="00433539" w:rsidtr="006C4206">
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="7615D6EE" w14:textid="6F7AC770" w:rsidr="00433539" w:rsidrdefault="00433539" w:rsidrpr="00490B75">
# <w:ppr>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t>B1</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4675"></w:tcw>
# <w:gridspan w:val="2"></w:gridspan>
# </w:tcpr>
# <w:p w14:paraid="3E9ECB6B" w14:textid="77777777" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>B2</w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="33E5A282" w14:textid="574CF6A4" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>B3</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="0B9820E8" w14:textid="76B7648B" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>B4</w:t>
# </w:r>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="157093CB" w14:textid="77777777" w:rsidr="00490B75" w:rsidtr="00490B75">
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="53C3E0E3" w14:textid="232404E8" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>C1</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="1C97389D" w14:textid="0A0B1F2B" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>C2</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="706391D5" w14:textid="27F584CB" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>C3</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="36DE9E6D" w14:textid="68EB4B79" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>C4</w:t>
# </w:r>
# </w:p>
# </w:tc>
# </w:tr>
# <w:tr w14:paraid="2DB08D7E" w14:textid="77777777" w:rsidr="00433539" w:rsidtr="00DC4123">
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4674"></w:tcw>
# <w:gridspan w:val="2"></w:gridspan>
# </w:tcpr>
# <w:p w14:paraid="5672F7A5" w14:textid="77777777" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>D1</w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="7E107837" w14:textid="265CF014" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>D2</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="58E0C253" w14:textid="017252BB" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>D3</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="418BDD2B" w14:textid="064A2367" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>D4</w:t>
# </w:r>
# </w:p>
# </w:tc>
# </w:tr>
# </w:tbl>

# %%
tblpr = Table.find_all('w:tblpr') #### find_all may be needed in case of more tables (need to check)

# tblpr = Table.find('w:tblpr')

pprint.pprint(tblpr)
# Out:
# [<w:tblpr>
# <w:tblstyle w:val="TableGrid"></w:tblstyle>
# <w:tblw w:type="auto" w:w="0"></w:tblw>
# <w:tbllook w:firstcolumn="1" w:firstrow="1" w:lastcolumn="0" w:lastrow="0" w:nohband="0" w:novband="1" w:val="04A0"></w:tbllook>
# </w:tblpr>]

# %%
tblgrid = Table.find_all('w:tblgrid') #### find the grid information of the table
# tblpr = Table.find('w:tblpr')

pprint.pprint(tblgrid)
# Out:
# [<w:tblgrid>
# <w:gridcol w:w="2337"></w:gridcol>
# <w:gridcol w:w="2337"></w:gridcol>
# <w:gridcol w:w="2338"></w:gridcol>
# <w:gridcol w:w="2338"></w:gridcol>
# </w:tblgrid>]

# %%
tr = Table.find_all('w:tr') #### find all the rows in the table

# tblpr = Table.find('w:tblpr')

pprint.pprint(tr)
# Out:
# [<w:tr w14:paraid="260A5970" w14:textid="77777777" w:rsidr="00490B75" w:rsidtr="00490B75">
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="18F63C89" w14:textid="6A8ABFB7" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>A1</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="397D01ED" w14:textid="34A23770" w:rsidr="00490B75" w:rsidrdefault="00490B75" w:rsidrpr="00490B75">
# <w:r>
# <w:t>A2</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="0BBFB6BF" w14:textid="5971FE64" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>A3</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="54D2621A" w14:textid="5261E162" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>A4</w:t>
# </w:r>
# </w:p>
# </w:tc>
# </w:tr>,
#  <w:tr w14:paraid="6633294A" w14:textid="77777777" w:rsidr="00433539" w:rsidtr="006C4206">
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="7615D6EE" w14:textid="6F7AC770" w:rsidr="00433539" w:rsidrdefault="00433539" w:rsidrpr="00490B75">
# <w:ppr>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:b></w:b>
# </w:rpr>
# <w:t>B1</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4675"></w:tcw>
# <w:gridspan w:val="2"></w:gridspan>
# </w:tcpr>
# <w:p w14:paraid="3E9ECB6B" w14:textid="77777777" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>B2</w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="33E5A282" w14:textid="574CF6A4" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>B3</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="0B9820E8" w14:textid="76B7648B" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>B4</w:t>
# </w:r>
# </w:p>
# </w:tc>
# </w:tr>,
#  <w:tr w14:paraid="157093CB" w14:textid="77777777" w:rsidr="00490B75" w:rsidtr="00490B75">
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="53C3E0E3" w14:textid="232404E8" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>C1</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="1C97389D" w14:textid="0A0B1F2B" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>C2</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="706391D5" w14:textid="27F584CB" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>C3</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="36DE9E6D" w14:textid="68EB4B79" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>C4</w:t>
# </w:r>
# </w:p>
# </w:tc>
# </w:tr>,
#  <w:tr w14:paraid="2DB08D7E" w14:textid="77777777" w:rsidr="00433539" w:rsidtr="00DC4123">
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="4674"></w:tcw>
# <w:gridspan w:val="2"></w:gridspan>
# </w:tcpr>
# <w:p w14:paraid="5672F7A5" w14:textid="77777777" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>D1</w:t>
# </w:r>
# </w:p>
# <w:p w14:paraid="7E107837" w14:textid="265CF014" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>D2</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="58E0C253" w14:textid="017252BB" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>D3</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="418BDD2B" w14:textid="064A2367" w:rsidr="00433539" w:rsidrdefault="00433539">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>D4</w:t>
# </w:r>
# </w:p>
# </w:tc>
# </w:tr>]

# %%
pprint.pprint(tr[2]) #####this are the rows #### a per row information to get a percolumn information
# Out:
# <w:tr w14:paraid="157093CB" w14:textid="77777777" w:rsidr="00490B75" w:rsidtr="00490B75">
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="53C3E0E3" w14:textid="232404E8" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>C1</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="1C97389D" w14:textid="0A0B1F2B" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>C2</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="706391D5" w14:textid="27F584CB" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>C3</w:t>
# </w:r>
# </w:p>
# </w:tc>
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="36DE9E6D" w14:textid="68EB4B79" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>C4</w:t>
# </w:r>
# </w:p>
# </w:tc>
# </w:tr>

# %%
tc = tr[0].find_all('w:tc')    ###### this is for finding each column

pprint.pprint(tc)
# Out:
# [<w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="18F63C89" w14:textid="6A8ABFB7" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>A1</w:t>
# </w:r>
# </w:p>
# </w:tc>,
#  <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2337"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="397D01ED" w14:textid="34A23770" w:rsidr="00490B75" w:rsidrdefault="00490B75" w:rsidrpr="00490B75">
# <w:r>
# <w:t>A2</w:t>
# </w:r>
# </w:p>
# </w:tc>,
#  <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="0BBFB6BF" w14:textid="5971FE64" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>A3</w:t>
# </w:r>
# </w:p>
# </w:tc>,
#  <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="54D2621A" w14:textid="5261E162" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>A4</w:t>
# </w:r>
# </w:p>
# </w:tc>]

# %%
pprint.pprint(tc[3]) #### this are the columns of each
# Out:
# <w:tc>
# <w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>
# <w:p w14:paraid="54D2621A" w14:textid="5261E162" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>A4</w:t>
# </w:r>
# </w:p>
# </w:tc>

# %%
tcpr = tc[3].find_all('w:tcpr')   ###### this is a per column data information is needed

pprint.pprint(tcpr)
# Out:
# [<w:tcpr>
# <w:tcw w:type="dxa" w:w="2338"></w:tcw>
# </w:tcpr>]

# %%
p = tc[3].find_all('w:p')   #### this is for finding each paragraph

pprint.pprint(p)
# Out:
# [<w:p w14:paraid="54D2621A" w14:textid="5261E162" w:rsidr="00490B75" w:rsidrdefault="00490B75">
# <w:ppr>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# </w:ppr>
# <w:r>
# <w:rpr>
# <w:u w:val="single"></w:u>
# </w:rpr>
# <w:t>A4</w:t>
# </w:r>
# </w:p>]

# %%
p[0].find_all('w:ppr')    ##### this needs to stay per paragraph
# Out:
# [<w:ppr>
#  <w:rpr>
#  <w:u w:val="single"></w:u>
#  </w:rpr>
#  </w:ppr>]

# %%
p[0].find_all('w:r')   ##### this needs to stay per paragraph
# Out:
# [<w:r>
#  <w:rpr>
#  <w:u w:val="single"></w:u>
#  </w:rpr>
#  <w:t>A4</w:t>
#  </w:r>]
